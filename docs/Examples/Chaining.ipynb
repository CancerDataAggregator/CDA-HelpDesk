# %% [markdown]
# # Endpoint Chaining
# ---

# %% [markdown]
# The CDA provides a custom python tool for searching CDA data. [`Q`](usage/#q) (short for Query) offers several ways to search and filter data, and several input modes:
#
# ---
# - **<a href="../../QuickStart/usage/#q">Q.()</a>** builds a query that can be used by `run()` or `count()`
# - **<a href="../../QuickStart/usage/#qrun">Q.run()</a>** returns data for the specified search
# - **<a href="../../QuickStart/usage/#qcount">Q.count()</a>** returns summary information (counts) data that fit the specified search
# - **<a href="../../QuickStart/usage/#columns">columns()</a>** returns entity field names
# - **<a href="../../QuickStart/usage/#unique_terms">unique_terms()</a>** returns entity field contents
#
# ---
#
# Before we do any work, we needs to import these functions cdapython.
# We're also telling cdapython to report it's version so we can be sure we're using the one we mean to:

# %%
from cdapython import Q, columns, unique_terms, query
import cdapython
print(Q.get_version())
# Out:
# 2022.6.28

# %%
Q.set_default_project_dataset("broad-dsde-dev.cda_dev")
Q.set_host_url("https://cancerdata.dsde-dev.broadinstitute.org/")
Q.get_host_url()
Q.get_default_project_dataset()
# Out:
# 'broad-dsde-dev.cda_dev'

# %% [markdown]
# ## Endpoint Chaining
#
# We're going to build on our <a href="../BasicSearch">previous basic search</a> to see what information exists about cancers that were first diagnosed in the brain.

# %%
myquery = Q('ResearchSubject.primary_diagnosis_site = "brain"')

# %% [markdown]
# Previously we looked at subject, research_subject, specimen and file results seperately, but we can also combine these.
#
# Let's say what we're really interested in is finding analysis done on specimens, so we're looking for files that belong to specimens that match our search. If we search the files endpoint directly, we'll get back all files that meet our search criteria, regardless of whether they are specimens specficially. Instead, we can chain our query to the specimen endpoint and then to the files endpoint and get the combined result:

# %%
myqueryspecimenfiles =  myquery.specimen.file.run()
myqueryspecimenfiles
# Out:
# Getting results from database
# Total execution time: 3938 ms
#             QueryID: 0a05eb3d-948d-4519-b30e-d94a59a5ed0a
#
#             Offset: 0
#             Count: 100
#             Total Row Count: 405271
#             More pages: True

# %% [markdown]
# We get back 405031 files that belong to specimens that meet our search criteria. As before, we can preview the results by using the `.to_dataframe()` function:

# %%
myqueryspecimenfiles.to_dataframe()
# Out:
#                                       id  \
# 0   00b5cc1e-e51a-4c5f-a98c-076acf265042
# 1   06668371-2079-4471-a06a-7ad6f987a96c
# 2   1958cd4c-263d-4a5e-ad69-8bae23a0edc7
# 3   19f0c787-654a-4cf6-ba8b-dca9e46bc220
# 4   22dbc627-b923-453e-8fe0-a6fbe76c66bc
# ..                                   ...
# 95  01f40d93-e2fe-46d9-b0db-5bb3be21d158
# 96  14b828c9-0eac-4613-9354-64dae9e7acf2
# 97  1825d954-56e3-4faa-991e-56e28d23f31e
# 98  311e41c3-017f-4f30-a858-abd99547c1d2
# 99  329ccbdc-8b9a-4cc2-ac28-007db73dc228
#
#                                            identifier  \
# 0   [{'system': 'GDC', 'value': '00b5cc1e-e51a-4c5...
# 1   [{'system': 'GDC', 'value': '06668371-2079-447...
# 2   [{'system': 'GDC', 'value': '1958cd4c-263d-4a5...
# 3   [{'system': 'GDC', 'value': '19f0c787-654a-4cf...
# 4   [{'system': 'GDC', 'value': '22dbc627-b923-453...
# ..                                                ...
# 95  [{'system': 'GDC', 'value': '01f40d93-e2fe-46d...
# 96  [{'system': 'GDC', 'value': '14b828c9-0eac-461...
# 97  [{'system': 'GDC', 'value': '1825d954-56e3-4fa...
# 98  [{'system': 'GDC', 'value': '311e41c3-017f-4f3...
# 99  [{'system': 'GDC', 'value': '329ccbdc-8b9a-4cc...
#
#                                                 label  \
# 0   4db50bc3-572f-48bf-a88a-2fd065496409.genie.ali...
# 1   5861e7d6-2066-40d7-8868-c14a69255304.genie.ali...
# 2           TCGA-HT-7477-01B-21-A29Z-20_RPPA_data.tsv
# 3           TCGA-QH-A65V-01A-21-A44D-20_RPPA_data.tsv
# 4   18235707-e320-40e6-8628-c17e8e004702.genie.ali...
# ..                                                ...
# 95  dd13f0a2-db35-4cec-9fa8-12b4830c9403.genie.ali...
# 96          TCGA-06-6388-01A-23-1900-20_RPPA_data.tsv
# 97  415b62cf-1ab3-4432-9fd4-c326718d8142.genie.ali...
# 98          TCGA-HT-7857-01A-21-A29Y-20_RPPA_data.tsv
# 99          TCGA-DU-7309-01A-21-A29X-20_RPPA_data.tsv
#
#                   data_category                          data_type  \
# 0   Simple Nucleotide Variation  Masked Annotated Somatic Mutation
# 1   Simple Nucleotide Variation  Masked Annotated Somatic Mutation
# 2            Proteome Profiling  Protein Expression Quantification
# 3            Proteome Profiling  Protein Expression Quantification
# 4         Copy Number Variation      Gene Level Copy Number Scores
# ..                          ...                                ...
# 95  Simple Nucleotide Variation  Masked Annotated Somatic Mutation
# 96           Proteome Profiling  Protein Expression Quantification
# 97        Copy Number Variation      Gene Level Copy Number Scores
# 98           Proteome Profiling  Protein Expression Quantification
# 99           Proteome Profiling  Protein Expression Quantification
#
#    file_format associated_project  \
# 0          MAF          GENIE-MSK
# 1          MAF          GENIE-NKI
# 2          TSV           TCGA-LGG
# 3          TSV           TCGA-LGG
# 4          TSV          GENIE-MSK
# ..         ...                ...
# 95         MAF         GENIE-GRCC
# 96         TSV           TCGA-GBM
# 97         TSV          GENIE-MSK
# 98         TSV           TCGA-LGG
# 99         TSV           TCGA-LGG
#
#                                               drs_uri  byte_size  \
# 0   drs://dg.4DFC:00b5cc1e-e51a-4c5f-a98c-076acf26...       1054
# 1   drs://dg.4DFC:06668371-2079-4471-a06a-7ad6f987...       1052
# 2   drs://dg.4DFC:1958cd4c-263d-4a5e-ad69-8bae23a0...      22089
# 3   drs://dg.4DFC:19f0c787-654a-4cf6-ba8b-dca9e46b...      21985
# 4   drs://dg.4DFC:22dbc627-b923-453e-8fe0-a6fbe76c...      22932
# ..                                                ...        ...
# 95  drs://dg.4DFC:01f40d93-e2fe-46d9-b0db-5bb3be21...       2753
# 96  drs://dg.4DFC:14b828c9-0eac-4613-9354-64dae9e7...      23942
# 97  drs://dg.4DFC:1825d954-56e3-4faa-991e-56e28d23...      22932
# 98  drs://dg.4DFC:311e41c3-017f-4f30-a858-abd99547...      22107
# 99  drs://dg.4DFC:329ccbdc-8b9a-4cc2-ac28-007db73d...      22009
#
#                             checksum data_modality imaging_modality  \
# 0   01b29f819d9447e65a1d4b8d80a93b4a       Genomic             None
# 1   e8d1a8534b9fe7a813f1b10a8a706daf       Genomic             None
# 2   ba575069e7c576eb3bf532fd16c164ac       Genomic             None
# 3   92f1aae376db4e1f4e5567cf33069fd3       Genomic             None
# 4   35562af5c759a3ac265c3db414f4529b       Genomic             None
# ..                               ...           ...              ...
# 95  758d9563a8348e7ba1479de7b5592977       Genomic             None
# 96  e750e4fc571db02b428ec510527dbf01       Genomic             None
# 97  78fb97b022c9790c89888ba62bfb222e       Genomic             None
# 98  d300e8a5dd261c8fa4181c7f790a805e       Genomic             None
# 99  f686ecd5d6e3c5d793a593f7e03da17d       Genomic             None
#
#    dbgap_accession_number imaging_series           subject_id  \
# 0                    None           None  GENIE-MSK-P-0019286
# 1                    None           None       GENIE-NKI-8IN3
# 2                    None           None         TCGA-HT-7477
# 3                    None           None         TCGA-QH-A65V
# 4                    None           None  GENIE-MSK-P-0003834
# ..                    ...            ...                  ...
# 95                   None           None  GENIE-GRCC-774ad24a
# 96                   None           None         TCGA-06-6388
# 97                   None           None  GENIE-MSK-P-0002086
# 98                   None           None         TCGA-HT-7857
# 99                   None           None         TCGA-DU-7309
#
#                       researchsubject_id           researchsubject_specimen_id
# 0   b1569de4-a705-47f0-842d-4369a3bf43a3  bfae3035-fc8b-5f5e-b2b4-37e817c4f827
# 1   54ada9c7-e8f7-4ecc-b829-903be7e3ad82  08b49bbe-09f0-447b-a193-f2c5a923c051
# 2   38f4b9f3-6709-40ff-9a81-5fa2111b1ce6  83cf2e54-8468-4e5c-b427-4134e046009c
# 3   ad72e61e-51e3-4992-ac77-65e895935736  c76aa96d-53f4-4ec0-a009-a1fbaed96e39
# 4   d500a0f9-02f9-4eee-b469-3f1cd361d563  d92a9d5d-5391-4913-89ab-09eda609675c
# ..                                   ...                                   ...
# 95  ebee5ebd-e037-455b-9071-1b0e6f033764  694c18df-47cd-4cf9-ac2e-8cedc3d2feb7
# 96  7eb1d526-923d-4b31-b8be-27d83b3dd025  673a0dc8-4bed-43df-9fb0-36fb546a5e58
# 97  864d18aa-dced-4faf-9cc7-dfb01092f760  30b60e4f-9e6b-490e-8b9f-e656a0798402
# 98  4e1606e5-f4c1-41a2-9f2c-ad0d02650070  a7357fa3-3468-4288-99c2-624d885d471c
# 99  ca427acb-034e-42e2-961a-b9d5dc30b741  21d6c002-65e0-4dcc-b5af-5c3adfd0e75c
#
# [100 rows x 17 columns]

# %% [markdown]
# <div class="cdanote" style="background-color:#b3e5d5;color:black;padding:20px;">
#
# <h3>Valid Endpoint Chains</h3>
#
# Not all endpoints can be chained together. This is a restriction caused by the data itself. `diagnosis` and `treatment` information does not have files directly attached to it, instead these files are associated with the `researchsubject`, as such both "myquery.treatment.files.run()" and "myquery.diagnosis.files.run()" will fail, as there are no files to retrieve. Valid chains are:
#
# <ul>
# <li><b>myquery.subject.file.run:</b> This will return all the files that meet the query and that are directly tied to subject</li>
# <li><b>myquery.researchsubject.file.run:</b>This will return all the files that meet the query and that are directly tied to researchsubject</li>
# <li><b>myquery.specimen.file.run:</b> This will return all the files that meet the query and that are directly tied to specimen</li>
# <li><b>myquery.subject.file.count.run:</b> This will return the count of files that meet the query and that are directly tied to subject</li>
# <li><b>myquery.researchsubject.file.count.run:</b>This will return the count of files that meet the query and that are directly tied to researchsubject</li>
# <li><b>myquery.specimen.file.count.run:</b> This will return the count of files that meet the query and that are directly tied to specimen</li>
# </ul>
# </div>
