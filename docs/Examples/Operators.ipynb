# %% [markdown]
# # Using Operators
# ---

# %% [markdown]
# Operators allow us to make more complex queries by adding, subtracting, or filtering data.
#
# `Q` uses the following operators:
#
# - [`=` : Equals](#equals)
# - [`!=` : Not Equal](#not-equal)
# - [`OR`](#or)
# - [`AND`](#and)
# - [`IN` and `NOT IN`](#in-and-not-in)
# - [`%`: pattern matching a wildcard](#pattern-matching)
# - [`IS` and `IS NOT`](#is-and-is-not)
# - [`>`, `>`, `>=`, `<=`: Greater and Less than](#greater-and-less-than)
#
#
#
# We use these operators to build more and more complex Q statements before sending our query to `run()` or `count()`.

# %% [markdown]
# The CDA provides a custom python tool for searching CDA data. [`Q`](usage/#q) (short for Query) offers several ways to search and filter data, and several input modes:
#
# ---
# - **<a href="../../QuickStart/usage/#q">Q.()</a>** builds a query that can be used by `run()` or `count()`
# - **<a href="../../QuickStart/usage/#qrun">Q.run()</a>** returns data for the specified search
# - **<a href="../../QuickStart/usage/#qcount">Q.count()</a>** returns summary information (counts) data that fit the specified search
# - **<a href="../../QuickStart/usage/#columns">columns()</a>** returns entity field names
# - **<a href="../../QuickStart/usage/#unique_terms">unique_terms()</a>** returns entity field contents
#
# ---
#
# Before we do any work, we needs to import these functions cdapython.
# We're also telling cdapython to report it's version so we can be sure we're using the one we mean to:

# %%
from cdapython import Q, columns, unique_terms, query
print(Q.get_version())
# Out:
# 2022.6.22

# %% [markdown]
# ## Equals: `=`
#
# In the other tutorials, we have always used the same query, which uses the `=` operator.
#
# ```Q('ResearchSubject.primary_diagnosis_site = "brain"')```
#
# This operator will only return data where the primary_diagnosis_site is exactly "brain". Here let's to a similar search, but for "uterus". We'll look at the researchsubject summary:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3281 ms
#     total : 867
#    files : 242362
# <style type="text/css">
# #T_83d7a_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_83d7a_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_83d7a_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83d7a_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_83d7a_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a8b6e_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_a8b6e_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_a8b6e_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a8b6e_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_a8b6e_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f7832_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f7832_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f7832_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f7832_row0_col0" class="data row0 col0" >Uterus</td>
#       <td id="T_f7832_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Not Equal: `!=`
#
# The `!=` operator does the opposite of the `=` operator, it returns everything that is not exactly the term you give it:

# %%
Q('ResearchSubject.primary_diagnosis_site != "uterus"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3373 ms
#    total : 148831
#   files : 39151844
# <style type="text/css">
# #T_f708d_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f708d_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f708d_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f708d_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_f708d_row0_col1" class="data row0 col1" >85416</td>
#     </tr>
#     <tr>
#       <td id="T_f708d_row1_col0" class="data row1 col0" >IDC</td>
#       <td id="T_f708d_row1_col1" class="data row1 col1" >61081</td>
#     </tr>
#     <tr>
#       <td id="T_f708d_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_f708d_row2_col1" class="data row2 col1" >2334</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d60f5_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d60f5_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d60f5_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d60f5_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_d60f5_row0_col1" class="data row0 col1" >32730</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row1_col0" class="data row1 col0" >Other</td>
#       <td id="T_d60f5_row1_col1" class="data row1 col1" >206</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row2_col0" class="data row2 col0" >Ductal and Lobular Neoplasms</td>
#       <td id="T_d60f5_row2_col1" class="data row2 col1" >7870</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_d60f5_row3_col1" class="data row3 col1" >61083</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row4_col0" class="data row4 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_d60f5_row4_col1" class="data row4 col1" >3723</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row5_col0" class="data row5 col0" >Gliomas</td>
#       <td id="T_d60f5_row5_col1" class="data row5 col1" >4772</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row6_col0" class="data row6 col0" >Lymphoid Leukemias</td>
#       <td id="T_d60f5_row6_col1" class="data row6 col1" >2072</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row7_col0" class="data row7 col0" >Pancreatic Ductal Adenocarcinoma</td>
#       <td id="T_d60f5_row7_col1" class="data row7 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row8_col0" class="data row8 col0" >Nevi and Melanomas</td>
#       <td id="T_d60f5_row8_col1" class="data row8 col1" >3155</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row9_col0" class="data row9 col0" >Germ Cell Neoplasms</td>
#       <td id="T_d60f5_row9_col1" class="data row9 col1" >703</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row10_col0" class="data row10 col0" >Myomatous Neoplasms</td>
#       <td id="T_d60f5_row10_col1" class="data row10 col1" >632</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row11_col0" class="data row11 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_d60f5_row11_col1" class="data row11 col1" >5076</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row12_col0" class="data row12 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_d60f5_row12_col1" class="data row12 col1" >1332</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row13_col0" class="data row13 col0" >Transitional Cell Papillomas and Carcinomas</td>
#       <td id="T_d60f5_row13_col1" class="data row13 col1" >1885</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row14_col0" class="data row14 col0" >Myeloid Leukemias</td>
#       <td id="T_d60f5_row14_col1" class="data row14 col1" >3965</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row15_col0" class="data row15 col0" >Mesothelial Neoplasms</td>
#       <td id="T_d60f5_row15_col1" class="data row15 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row16_col0" class="data row16 col0" >Not Reported</td>
#       <td id="T_d60f5_row16_col1" class="data row16 col1" >271</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row17_col0" class="data row17 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_d60f5_row17_col1" class="data row17 col1" >5694</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row18_col0" class="data row18 col0" >Glioblastoma</td>
#       <td id="T_d60f5_row18_col1" class="data row18 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row19_col0" class="data row19 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_d60f5_row19_col1" class="data row19 col1" >1826</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row20_col0" class="data row20 col0" >Mature B-Cell Lymphomas</td>
#       <td id="T_d60f5_row20_col1" class="data row20 col1" >1019</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row21_col0" class="data row21 col0" >Thymic Epithelial Neoplasms</td>
#       <td id="T_d60f5_row21_col1" class="data row21 col1" >262</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row22_col0" class="data row22 col0" >Clear Cell Renal Cell Carcinoma</td>
#       <td id="T_d60f5_row22_col1" class="data row22 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row23_col0" class="data row23 col0" >Paragangliomas and Glomus Tumors</td>
#       <td id="T_d60f5_row23_col1" class="data row23 col1" >241</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row24_col0" class="data row24 col0" >Plasma Cell Tumors</td>
#       <td id="T_d60f5_row24_col1" class="data row24 col1" >1066</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row25_col0" class="data row25 col0" >Neoplasms, NOS</td>
#       <td id="T_d60f5_row25_col1" class="data row25 col1" >1251</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row26_col0" class="data row26 col0" >Breast Invasive Carcinoma</td>
#       <td id="T_d60f5_row26_col1" class="data row26 col1" >251</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row27_col0" class="data row27 col0" >Lung Squamous Cell Carcinoma</td>
#       <td id="T_d60f5_row27_col1" class="data row27 col1" >118</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row28_col0" class="data row28 col0" >Chronic Myeloproliferative Disorders</td>
#       <td id="T_d60f5_row28_col1" class="data row28 col1" >476</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row29_col0" class="data row29 col0" >Lung Adenocarcinoma</td>
#       <td id="T_d60f5_row29_col1" class="data row29 col1" >216</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row30_col0" class="data row30 col0" >Colon Adenocarcinoma</td>
#       <td id="T_d60f5_row30_col1" class="data row30 col1" >164</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row31_col0" class="data row31 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_d60f5_row31_col1" class="data row31 col1" >254</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row32_col0" class="data row32 col0" >Lipomatous Neoplasms</td>
#       <td id="T_d60f5_row32_col1" class="data row32 col1" >343</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row33_col0" class="data row33 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_d60f5_row33_col1" class="data row33 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row34_col0" class="data row34 col0" >Osseous and Chondromatous Neoplasms</td>
#       <td id="T_d60f5_row34_col1" class="data row34 col1" >615</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row35_col0" class="data row35 col0" >Ovarian Serous Cystadenocarcinoma</td>
#       <td id="T_d60f5_row35_col1" class="data row35 col1" >283</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row36_col0" class="data row36 col0" >Nerve Sheath Tumors</td>
#       <td id="T_d60f5_row36_col1" class="data row36 col1" >115</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row37_col0" class="data row37 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_d60f5_row37_col1" class="data row37 col1" >315</td>
#     </tr>
#     <tr>
#       <td id="T_d60f5_row38_col0" class="data

# %% [markdown]
# Note that in our `!=` results, there are 2000 "Uterus, NOS" samples. These don't appear in our `=` search because "Uterus, NOS" is not *exactly* "Uterus".
#
# There are several ways to change our search to get both "Uterus" and "Uterus, NOS", and which we choose will depend on both our interests, and on how different the terms are that we care about.

# %% [markdown]
# ## OR
#
# If we have a small enough number of search criteria to reliably type them out, we can use the OR operator to combine results. In an `OR` query, each data point only needs to meet a single piece of criteria to be returned, this makes `OR` good for early, broad searches. It *increases* the amount of data returned.
#
# `OR` can be used both inside a Q statement:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus" OR ResearchSubject.primary_diagnosis_site = "uterus, NOS"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3318 ms
#     total : 2865
#    files : 257140
# <style type="text/css">
# #T_060a5_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_060a5_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_060a5_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_060a5_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_060a5_row0_col1" class="data row0 col1" >1894</td>
#     </tr>
#     <tr>
#       <td id="T_060a5_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_060a5_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_060a5_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_060a5_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_452bd_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_452bd_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_452bd_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_452bd_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_452bd_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row1_col0" class="data row1 col0" >Not Reported</td>
#       <td id="T_452bd_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row2_col0" class="data row2 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_452bd_row2_col1" class="data row2 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row3_col0" class="data row3 col0" >Myomatous Neoplasms</td>
#       <td id="T_452bd_row3_col1" class="data row3 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row4_col0" class="data row4 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_452bd_row4_col1" class="data row4 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_452bd_row5_col1" class="data row5 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row6_col0" class="data row6 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_452bd_row6_col1" class="data row6 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row7_col0" class="data row7 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_452bd_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row8_col0" class="data row8 col0" >Trophoblastic neoplasms</td>
#       <td id="T_452bd_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row9_col0" class="data row9 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_452bd_row9_col1" class="data row9 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row10_col0" class="data row10 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_452bd_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row11_col0" class="data row11 col0" >Neoplasms, NOS</td>
#       <td id="T_452bd_row11_col1" class="data row11 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row12_col0" class="data row12 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_452bd_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_452bd_row13_col0" class="data row13 col0" >Mesonephromas</td>
#       <td id="T_452bd_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_230bb_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_230bb_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_230bb_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_230bb_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_230bb_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_230bb_row1_col0" class="data row1 col0" >Uterus</td>
#       <td id="T_230bb_row1_col1" class="data row1 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# and to combine 2 or more Q statements:

# %%
Query1 = Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS"') 
Query2 = Q('ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"')

Query1.OR(Query2).researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3315 ms
#     total : 1998
#    files : 14778
# <style type="text/css">
# #T_52cf8_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_52cf8_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_52cf8_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52cf8_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_52cf8_row0_col1" class="data row0 col1" >1894</td>
#     </tr>
#     <tr>
#       <td id="T_52cf8_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_52cf8_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c52e3_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_c52e3_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_c52e3_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c52e3_row0_col0" class="data row0 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_c52e3_row0_col1" class="data row0 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row1_col0" class="data row1 col0" >Myomatous Neoplasms</td>
#       <td id="T_c52e3_row1_col1" class="data row1 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row2_col0" class="data row2 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_c52e3_row2_col1" class="data row2 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row3_col0" class="data row3 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_c52e3_row3_col1" class="data row3 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row4_col0" class="data row4 col0" >Not Reported</td>
#       <td id="T_c52e3_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row5_col0" class="data row5 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_c52e3_row5_col1" class="data row5 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row6_col0" class="data row6 col0" >Trophoblastic neoplasms</td>
#       <td id="T_c52e3_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row7_col0" class="data row7 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_c52e3_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row8_col0" class="data row8 col0" >Neoplasms, NOS</td>
#       <td id="T_c52e3_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row9_col0" class="data row9 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_c52e3_row9_col1" class="data row9 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row10_col0" class="data row10 col0" >Mesonephromas</td>
#       <td id="T_c52e3_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row11_col0" class="data row11 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_c52e3_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_c52e3_row12_col0" class="data row12 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_c52e3_row12_col1" class="data row12 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7ecaa_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7ecaa_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7ecaa_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7ecaa_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_7ecaa_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For each `OR` you must specify both the search term ("uterus") and where to find the term ("ResearchSubject.primary_diagnosis_site"). This means that the `OR` operator is flexible enough to run searches across columns, or even across endpoints.

# %% [markdown]
# ## AND
#
# Like `OR`, `AND` can be used both inside a Q statement, and to join multiple Q statements. `AND` requires that both statements be true simultanously for each returned bit of data. This makes `AND` good for filtering down results. It *decreases* the amount of data returned.
#
# If we reuse the `OR` examples above, the first one will have no results, because primary_diagnosis_site can have only one value, so it can never be both "uterus" and "uterus, NOS":

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus" AND ResearchSubject.primary_diagnosis_site = "uterus, NOS"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3434 ms
#      total : 0
#      files : 0
# <style type="text/css">
# #T_b0a75_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b0a75_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b0a75_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ab116_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_ab116_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_ab116_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a7965_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_a7965_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_a7965_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# However, for searches where you are interested in subsetting multiple columns, `AND` can help you to quickly filter to only the set you want. Note that `AND` can be used both inside a `Q` statement, and to add multiple `Q` statements together:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS" AND ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3374 ms
#     total : 104
#     files : 2560
# <style type="text/css">
# #T_d4205_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d4205_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d4205_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d4205_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_d4205_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_30514_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_30514_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_30514_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_30514_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_30514_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c710d_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_c710d_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_c710d_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c710d_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_c710d_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>

# %%
Query1 = Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS"') 
Query2 = Q('ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"')

Query1.AND(Query2).researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3248 ms
#     total : 104
#     files : 2560
# <style type="text/css">
# #T_f8641_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f8641_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f8641_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8641_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_f8641_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_09474_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_09474_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_09474_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09474_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_09474_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0fa2a_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_0fa2a_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_0fa2a_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0fa2a_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_0fa2a_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `IN` and `NOT IN`
#
# For instances where you have many search terms, it may be easier (and more readable) to use `IN`. With `IN` you make a list of all the terms you are interested in, and ask whether they are `IN` a given field:

# %%
Q('ResearchSubject.primary_diagnosis_site IN ("uterus, NOS", "uterus", "Cervix", "Cervix uteri")').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3232 ms
#     total : 4087
#    files : 299493
# <style type="text/css">
# #T_9d7a0_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_9d7a0_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_9d7a0_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d7a0_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_9d7a0_row0_col1" class="data row0 col1" >2809</td>
#     </tr>
#     <tr>
#       <td id="T_9d7a0_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_9d7a0_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_9d7a0_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_9d7a0_row2_col1" class="data row2 col1" >1174</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b5dcb_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b5dcb_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b5dcb_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b5dcb_row0_col0" class="data row0 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_b5dcb_row0_col1" class="data row0 col1" >609</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row1_col0" class="data row1 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_b5dcb_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row2_col0" class="data row2 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_b5dcb_row2_col1" class="data row2 col1" >1264</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row3_col0" class="data row3 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_b5dcb_row3_col1" class="data row3 col1" >348</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row4_col0" class="data row4 col0" >Myomatous Neoplasms</td>
#       <td id="T_b5dcb_row4_col1" class="data row4 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_b5dcb_row5_col1" class="data row5 col1" >1175</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row6_col0" class="data row6 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_b5dcb_row6_col1" class="data row6 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row7_col0" class="data row7 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_b5dcb_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row8_col0" class="data row8 col0" >Neoplasms, NOS</td>
#       <td id="T_b5dcb_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row9_col0" class="data row9 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_b5dcb_row9_col1" class="data row9 col1" >26</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row10_col0" class="data row10 col0" >Trophoblastic neoplasms</td>
#       <td id="T_b5dcb_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row11_col0" class="data row11 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_b5dcb_row11_col1" class="data row11 col1" >27</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row12_col0" class="data row12 col0" >Not Reported</td>
#       <td id="T_b5dcb_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row13_col0" class="data row13 col0" >Mesonephromas</td>
#       <td id="T_b5dcb_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b5dcb_row14_col0" class="data row14 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_b5dcb_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_880e9_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_880e9_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_880e9_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_880e9_row0_col0" class="data row0 col0" >Cervix uteri</td>
#       <td id="T_880e9_row0_col1" class="data row0 col1" >915</td>
#     </tr>
#     <tr>
#       <td id="T_880e9_row1_col0" class="data row1 col0" >Uterus, NOS</td>
#       <td id="T_880e9_row1_col1" class="data row1 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_880e9_row2_col0" class="data row2 col0" >Uterus</td>
#       <td id="T_880e9_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_880e9_row3_col0" class="data row3 col0" >Cervix</td>
#       <td id="T_880e9_row3_col1" class="data row3 col1" >307</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The equivilent request without `IN` would require a large number of `OR` statements. (The triple quotes surrounding this example are to allow a multi-line Q statement):
#
# ``` py
# Q("""ResearchSubject.primary_diagnosis_site = "uterus, NOS" OR
#       ResearchSubject.primary_diagnosis_site = "uterus" OR
#       ResearchSubject.primary_diagnosis_site = "Cervix" OR
#       ResearchSubject.primary_diagnosis_site = "Cervix uteri" """).researchsubject.count.run()
#
# ```

# %% [markdown]
# `NOT IN` is the opposite of `IN`, and so gives the inverse results. If we add `NOT` to our above query, we get all the researchsubjects who's primary_diagnosis_site was not in our list:

# %%
Q('ResearchSubject.primary_diagnosis_site NOT IN ("uterus, NOS", "uterus", "Cervix", "Cervix uteri")').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3232 ms
#    total : 145611
#   files : 39097313
# <style type="text/css">
# #T_30336_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_30336_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_30336_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_30336_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_30336_row0_col1" class="data row0 col1" >82607</td>
#     </tr>
#     <tr>
#       <td id="T_30336_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_30336_row1_col1" class="data row1 col1" >2230</td>
#     </tr>
#     <tr>
#       <td id="T_30336_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_30336_row2_col1" class="data row2 col1" >60774</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f75b3_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f75b3_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f75b3_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f75b3_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_f75b3_row0_col1" class="data row0 col1" >31466</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row1_col0" class="data row1 col0" >Other</td>
#       <td id="T_f75b3_row1_col1" class="data row1 col1" >206</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row2_col0" class="data row2 col0" >Ductal and Lobular Neoplasms</td>
#       <td id="T_f75b3_row2_col1" class="data row2 col1" >7870</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_f75b3_row3_col1" class="data row3 col1" >60775</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row4_col0" class="data row4 col0" >Plasma Cell Tumors</td>
#       <td id="T_f75b3_row4_col1" class="data row4 col1" >1066</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row5_col0" class="data row5 col0" >Lymphoid Leukemias</td>
#       <td id="T_f75b3_row5_col1" class="data row5 col1" >2072</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row6_col0" class="data row6 col0" >Myeloid Leukemias</td>
#       <td id="T_f75b3_row6_col1" class="data row6 col1" >3965</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row7_col0" class="data row7 col0" >Nevi and Melanomas</td>
#       <td id="T_f75b3_row7_col1" class="data row7 col1" >3155</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row8_col0" class="data row8 col0" >Pancreatic Ductal Adenocarcinoma</td>
#       <td id="T_f75b3_row8_col1" class="data row8 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row9_col0" class="data row9 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_f75b3_row9_col1" class="data row9 col1" >1331</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row10_col0" class="data row10 col0" >Myomatous Neoplasms</td>
#       <td id="T_f75b3_row10_col1" class="data row10 col1" >449</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row11_col0" class="data row11 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_f75b3_row11_col1" class="data row11 col1" >4467</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row12_col0" class="data row12 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_f75b3_row12_col1" class="data row12 col1" >5668</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row13_col0" class="data row13 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_f75b3_row13_col1" class="data row13 col1" >3375</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row14_col0" class="data row14 col0" >Transitional Cell Papillomas and Carcinomas</td>
#       <td id="T_f75b3_row14_col1" class="data row14 col1" >1885</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row15_col0" class="data row15 col0" >Miscellaneous Tumors</td>
#       <td id="T_f75b3_row15_col1" class="data row15 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row16_col0" class="data row16 col0" >Gliomas</td>
#       <td id="T_f75b3_row16_col1" class="data row16 col1" >4772</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row17_col0" class="data row17 col0" >Mesothelial Neoplasms</td>
#       <td id="T_f75b3_row17_col1" class="data row17 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row18_col0" class="data row18 col0" >Glioblastoma</td>
#       <td id="T_f75b3_row18_col1" class="data row18 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row19_col0" class="data row19 col0" >Fibromatous Neoplasms</td>
#       <td id="T_f75b3_row19_col1" class="data row19 col1" >322</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row20_col0" class="data row20 col0" >Meningiomas</td>
#       <td id="T_f75b3_row20_col1" class="data row20 col1" >289</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row21_col0" class="data row21 col0" >Thymic Epithelial Neoplasms</td>
#       <td id="T_f75b3_row21_col1" class="data row21 col1" >262</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row22_col0" class="data row22 col0" >Clear Cell Renal Cell Carcinoma</td>
#       <td id="T_f75b3_row22_col1" class="data row22 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row23_col0" class="data row23 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_f75b3_row23_col1" class="data row23 col1" >1532</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row24_col0" class="data row24 col0" >Mature B-Cell Lymphomas</td>
#       <td id="T_f75b3_row24_col1" class="data row24 col1" >1019</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row25_col0" class="data row25 col0" >Germ Cell Neoplasms</td>
#       <td id="T_f75b3_row25_col1" class="data row25 col1" >703</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row26_col0" class="data row26 col0" >Lung Squamous Cell Carcinoma</td>
#       <td id="T_f75b3_row26_col1" class="data row26 col1" >118</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row27_col0" class="data row27 col0" >Lung Adenocarcinoma</td>
#       <td id="T_f75b3_row27_col1" class="data row27 col1" >216</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row28_col0" class="data row28 col0" >Colon Adenocarcinoma</td>
#       <td id="T_f75b3_row28_col1" class="data row28 col1" >164</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row29_col0" class="data row29 col0" >Nerve Sheath Tumors</td>
#       <td id="T_f75b3_row29_col1" class="data row29 col1" >115</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row30_col0" class="data row30 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_f75b3_row30_col1" class="data row30 col1" >227</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row31_col0" class="data row31 col0" >Lipomatous Neoplasms</td>
#       <td id="T_f75b3_row31_col1" class="data row31 col1" >343</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row32_col0" class="data row32 col0" >Breast Invasive Carcinoma</td>
#       <td id="T_f75b3_row32_col1" class="data row32 col1" >251</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row33_col0" class="data row33 col0" >Osseous and Chondromatous Neoplasms</td>
#       <td id="T_f75b3_row33_col1" class="data row33 col1" >615</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row34_col0" class="data row34 col0" >Oral Squamous Cell Carcinoma</td>
#       <td id="T_f75b3_row34_col1" class="data row34 col1" >38</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row35_col0" class="data row35 col0" >Paragangliomas and Glomus Tumors</td>
#       <td id="T_f75b3_row35_col1" class="data row35 col1" >241</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row36_col0" class="data row36 col0" >Ovarian Serous Cystadenocarcinoma</td>
#       <td id="T_f75b3_row36_col1" class="data row36 col1" >283</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row37_col0" class="data row37 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_f75b3_row37_col1" class="data row37 col1" >301</td>
#     </tr>
#     <tr>
#       <td id="T_f75b3_row38_col0" class="data row38 col0" >Hepatoc

# %% [markdown]
# ## `%` pattern matching
#
# While `OR` is useful for situations with only a few options, in some cases there are many terms that all have similar names, and it would be error prone to type out every variant. For instance, if we filter the unique terms in "ResearchSubject.primary_diagnosis_site" to everything with "uter" we get:

# %%
unique_terms("ResearchSubject.primary_diagnosis_site").to_list(filters="uter")
# Out:
# ['Cervix uteri', 'Corpus uteri', 'Uterus', 'Uterus, NOS']

# %% [markdown]
# The `%` operator acts as a wildcard, and lets you run a query similar to the filter function in unique_terms:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uter%"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3234 ms
#     total : 2865
#    files : 257140
# <style type="text/css">
# #T_6676f_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_6676f_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_6676f_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6676f_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_6676f_row0_col1" class="data row0 col1" >1894</td>
#     </tr>
#     <tr>
#       <td id="T_6676f_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_6676f_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_6676f_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_6676f_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7d26c_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7d26c_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7d26c_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d26c_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_7d26c_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row1_col0" class="data row1 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_7d26c_row1_col1" class="data row1 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row2_col0" class="data row2 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_7d26c_row2_col1" class="data row2 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_7d26c_row3_col1" class="data row3 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row4_col0" class="data row4 col0" >Myomatous Neoplasms</td>
#       <td id="T_7d26c_row4_col1" class="data row4 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row5_col0" class="data row5 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_7d26c_row5_col1" class="data row5 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row6_col0" class="data row6 col0" >Mesonephromas</td>
#       <td id="T_7d26c_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row7_col0" class="data row7 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_7d26c_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row8_col0" class="data row8 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_7d26c_row8_col1" class="data row8 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row9_col0" class="data row9 col0" >Trophoblastic neoplasms</td>
#       <td id="T_7d26c_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row10_col0" class="data row10 col0" >Neoplasms, NOS</td>
#       <td id="T_7d26c_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row11_col0" class="data row11 col0" >Not Reported</td>
#       <td id="T_7d26c_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row12_col0" class="data row12 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_7d26c_row12_col1" class="data row12 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7d26c_row13_col0" class="data row13 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_7d26c_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_04431_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_04431_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_04431_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04431_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_04431_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_04431_row1_col0" class="data row1 col0" >Uterus</td>
#       <td id="T_04431_row1_col1" class="data row1 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Because the `%` is at the end of "uter" this query returns anything that starts with "uter", depending on your question, you may want to move the `%`, or add more of them:

# %%
Q('ResearchSubject.primary_diagnosis_site = "%uter"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3266 ms
#      total : 0
#      files : 0
# <style type="text/css">
# #T_184ae_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_184ae_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_184ae_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3d220_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_3d220_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_3d220_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c0293_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_c0293_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_c0293_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
Q('ResearchSubject.primary_diagnosis_site = "%uter%"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3310 ms
#     total : 4560
#    files : 302149
# <style type="text/css">
# #T_5974c_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_5974c_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_5974c_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5974c_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_5974c_row0_col1" class="data row0 col1" >3589</td>
#     </tr>
#     <tr>
#       <td id="T_5974c_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_5974c_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_5974c_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_5974c_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3b452_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_3b452_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_3b452_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b452_row0_col0" class="data row0 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_3b452_row0_col1" class="data row0 col1" >609</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row1_col0" class="data row1 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_3b452_row1_col1" class="data row1 col1" >1671</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row2_col0" class="data row2 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_3b452_row2_col1" class="data row2 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row3_col0" class="data row3 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_3b452_row3_col1" class="data row3 col1" >487</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row4_col0" class="data row4 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_3b452_row4_col1" class="data row4 col1" >320</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_3b452_row5_col1" class="data row5 col1" >868</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row6_col0" class="data row6 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_3b452_row6_col1" class="data row6 col1" >230</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row7_col0" class="data row7 col0" >Myomatous Neoplasms</td>
#       <td id="T_3b452_row7_col1" class="data row7 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row8_col0" class="data row8 col0" >Neoplasms, NOS</td>
#       <td id="T_3b452_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row9_col0" class="data row9 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_3b452_row9_col1" class="data row9 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row10_col0" class="data row10 col0" >Trophoblastic neoplasms</td>
#       <td id="T_3b452_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row11_col0" class="data row11 col0" >Mesonephromas</td>
#       <td id="T_3b452_row11_col1" class="data row11 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row12_col0" class="data row12 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_3b452_row12_col1" class="data row12 col1" >27</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row13_col0" class="data row13 col0" >Not Reported</td>
#       <td id="T_3b452_row13_col1" class="data row13 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3b452_row14_col0" class="data row14 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_3b452_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7878b_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7878b_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7878b_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7878b_row0_col0" class="data row0 col0" >Corpus uteri</td>
#       <td id="T_7878b_row0_col1" class="data row0 col1" >780</td>
#     </tr>
#     <tr>
#       <td id="T_7878b_row1_col0" class="data row1 col0" >Cervix uteri</td>
#       <td id="T_7878b_row1_col1" class="data row1 col1" >915</td>
#     </tr>
#     <tr>
#       <td id="T_7878b_row2_col0" class="data row2 col0" >Uterus, NOS</td>
#       <td id="T_7878b_row2_col1" class="data row2 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_7878b_row3_col0" class="data row3 col0" >Uterus</td>
#       <td id="T_7878b_row3_col1" class="data row3 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There may be cases in which you want to filter out all of the data with some partial word in it, in which case, you can combine `%` with `!=`:

# %%
Q('sex != "f%"').subject.count.run()
# Out:
# Getting results from database
# Total execution time: 3231 ms
#    total : 91361
#   files : 37815169
# <style type="text/css">
# #T_6eb05_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_6eb05_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_6eb05_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6eb05_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_6eb05_row0_col1" class="data row0 col1" >56038</td>
#     </tr>
#     <tr>
#       <td id="T_6eb05_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_6eb05_row1_col1" class="data row1 col1" >40024</td>
#     </tr>
#     <tr>
#       <td id="T_6eb05_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_6eb05_row2_col1" class="data row2 col1" >1089</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7d2c7_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7d2c7_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7d2c7_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d2c7_row0_col0" class="data row0 col0" >not reported</td>
#       <td id="T_7d2c7_row0_col1" class="data row0 col1" >266</td>
#     </tr>
#     <tr>
#       <td id="T_7d2c7_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_7d2c7_row1_col1" class="data row1 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_7d2c7_row2_col0" class="data row2 col0" >male</td>
#       <td id="T_7d2c7_row2_col1" class="data row2 col1" >39793</td>
#     </tr>
#     <tr>
#       <td id="T_7d2c7_row3_col0" class="data row3 col0" >unspecified</td>
#       <td id="T_7d2c7_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_7d2c7_row4_col0" class="data row4 col0" >unknown</td>
#       <td id="T_7d2c7_row4_col1" class="data row4 col1" >81</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_606b3_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_606b3_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_606b3_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >race</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_606b3_row0_col0" class="data row0 col0" >white</td>
#       <td id="T_606b3_row0_col1" class="data row0 col1" >23406</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_606b3_row1_col1" class="data row1 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row2_col0" class="data row2 col0" >chinese</td>
#       <td id="T_606b3_row2_col1" class="data row2 col1" >65</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row3_col0" class="data row3 col0" >asian</td>
#       <td id="T_606b3_row3_col1" class="data row3 col1" >1348</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row4_col0" class="data row4 col0" >black or african american</td>
#       <td id="T_606b3_row4_col1" class="data row4 col1" >1815</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row5_col0" class="data row5 col0" >not reported</td>
#       <td id="T_606b3_row5_col1" class="data row5 col1" >9881</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row6_col0" class="data row6 col0" >not allowed to collect</td>
#       <td id="T_606b3_row6_col1" class="data row6 col1" >1106</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row7_col0" class="data row7 col0" >Unknown</td>
#       <td id="T_606b3_row7_col1" class="data row7 col1" >2027</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row8_col0" class="data row8 col0" >american indian or alaska native</td>
#       <td id="T_606b3_row8_col1" class="data row8 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row9_col0" class="data row9 col0" >other</td>
#       <td id="T_606b3_row9_col1" class="data row9 col1" >415</td>
#     </tr>
#     <tr>
#       <td id="T_606b3_row10_col0" class="data row10 col0" >native hawaiian or other pacific islander</td>
#       <td id="T_606b3_row10_col1" class="data row10 col1" >26</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e96c5_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_e96c5_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_e96c5_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >ethnicity</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e96c5_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_e96c5_row0_col1" class="data row0 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_e96c5_row1_col0" class="data row1 col0" >not hispanic or latino</td>
#       <td id="T_e96c5_row1_col1" class="data row1 col1" >23020</td>
#     </tr>
#     <tr>
#       <td id="T_e96c5_row2_col0" class="data row2 col0" >not reported</td>
#       <td id="T_e96c5_row2_col1" class="data row2 col1" >11796</td>
#     </tr>
#     <tr>
#       <td id="T_e96c5_row3_col0" class="data row3 col0" >hispanic or latino</td>
#       <td id="T_e96c5_row3_col1" class="data row3 col1" >1450</td>
#     </tr>
#     <tr>
#       <td id="T_e96c5_row4_col0" class="data row4 col0" >Unknown</td>
#       <td id="T_e96c5_row4_col1" class="data row4 col1" >2293</td>
#     </tr>
#     <tr>
#       <td id="T_e96c5_row5_col0" class="data row5 col0" >not allowed to collect</td>
#       <td id="T_e96c5_row5_col1" class="data row5 col1" >1586</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_57ee1_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_57ee1_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_57ee1_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >cause_of_death</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_57ee1_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_57ee1_row0_col1" class="data row0 col1" >90714</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row1_col0" class="data row1 col0" >HCC recurrence</td>
#       <td id="T_57ee1_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row2_col0" class="data row2 col0" >Not Reported</td>
#       <td id="T_57ee1_row2_col1" class="data row2 col1" >335</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row3_col0" class="data row3 col0" >Cancer Related</td>
#       <td id="T_57ee1_row3_col1" class="data row3 col1" >198</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row4_col0" class="data row4 col0" >Unknown</td>
#       <td id="T_57ee1_row4_col1" class="data row4 col1" >22</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row5_col0" class="data row5 col0" >Not Cancer Related</td>
#       <td id="T_57ee1_row5_col1" class="data row5 col1" >76</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row6_col0" class="data row6 col0" >Surgical Complications</td>
#       <td id="T_57ee1_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row7_col0" class="data row7 col0" >Cardiovascular Disorder, NOS</td>
#       <td id="T_57ee1_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row8_col0" class="data row8 col0" >Infection</td>
#       <td id="T_57ee1_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row9_col0" class="data row9 col0" >Cerebral Hemorrhage</td>
#       <td id="T_57ee1_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_57ee1_row10_col0" class="data row10 col0" >Metastasis</td>
#       <td id="T_57ee1_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## IS and IS NOT
#
# In computing, lack of data is often treated as a special case. In the CDA, values listed as "None" are actually `null`, that is, the field is empty. In order to search for emptiness, you need to use the special function `IS`:

# %%
Q('ResearchSubject.primary_diagnosis_condition IS null').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3266 ms
#    total : 61950
#   files : 38475829
# <style type="text/css">
# #T_08ac7_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_08ac7_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_08ac7_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_08ac7_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_08ac7_row0_col1" class="data row0 col1" >61948</td>
#     </tr>
#     <tr>
#       <td id="T_08ac7_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_08ac7_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4a26e_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_4a26e_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_4a26e_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4a26e_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_4a26e_row0_col1" class="data row0 col1" >61950</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_041f7_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_041f7_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_041f7_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_041f7_row0_col0" class="data row0 col0" >Ovary</td>
#       <td id="T_041f7_row0_col1" class="data row0 col1" >664</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row1_col0" class="data row1 col0" >Head-Neck</td>
#       <td id="T_041f7_row1_col1" class="data row1 col1" >2704</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row2_col0" class="data row2 col0" >Colon</td>
#       <td id="T_041f7_row2_col1" class="data row2 col1" >1491</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row3_col0" class="data row3 col0" >Breast</td>
#       <td id="T_041f7_row3_col1" class="data row3 col1" >12587</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row4_col0" class="data row4 col0" >Chest</td>
#       <td id="T_041f7_row4_col1" class="data row4 col1" >28221</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row5_col0" class="data row5 col0" >Lung</td>
#       <td id="T_041f7_row5_col1" class="data row5 col1" >4728</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row6_col0" class="data row6 col0" >Abdomen</td>
#       <td id="T_041f7_row6_col1" class="data row6 col1" >92</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row7_col0" class="data row7 col0" >Various</td>
#       <td id="T_041f7_row7_col1" class="data row7 col1" >449</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row8_col0" class="data row8 col0" >Brain</td>
#       <td id="T_041f7_row8_col1" class="data row8 col1" >1165</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row9_col0" class="data row9 col0" >Abdomen, Mediastinum</td>
#       <td id="T_041f7_row9_col1" class="data row9 col1" >176</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row10_col0" class="data row10 col0" >Uterus</td>
#       <td id="T_041f7_row10_col1" class="data row10 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row11_col0" class="data row11 col0" >Kidney</td>
#       <td id="T_041f7_row11_col1" class="data row11 col1" >1373</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row12_col0" class="data row12 col0" >Pancreas</td>
#       <td id="T_041f7_row12_col1" class="data row12 col1" >481</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row13_col0" class="data row13 col0" >Various (11 locations)</td>
#       <td id="T_041f7_row13_col1" class="data row13 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row14_col0" class="data row14 col0" >Skin</td>
#       <td id="T_041f7_row14_col1" class="data row14 col1" >612</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row15_col0" class="data row15 col0" >Head</td>
#       <td id="T_041f7_row15_col1" class="data row15 col1" >105</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row16_col0" class="data row16 col0" >Liver</td>
#       <td id="T_041f7_row16_col1" class="data row16 col1" >452</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row17_col0" class="data row17 col0" >Prostate</td>
#       <td id="T_041f7_row17_col1" class="data row17 col1" >2139</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row18_col0" class="data row18 col0" >Pelvis, Prostate, Anus</td>
#       <td id="T_041f7_row18_col1" class="data row18 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row19_col0" class="data row19 col0" >Phantom</td>
#       <td id="T_041f7_row19_col1" class="data row19 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row20_col0" class="data row20 col0" >Extremities</td>
#       <td id="T_041f7_row20_col1" class="data row20 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row21_col0" class="data row21 col0" >Testicles</td>
#       <td id="T_041f7_row21_col1" class="data row21 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row22_col0" class="data row22 col0" >Bladder</td>
#       <td id="T_041f7_row22_col1" class="data row22 col1" >431</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row23_col0" class="data row23 col0" >Rectum</td>
#       <td id="T_041f7_row23_col1" class="data row23 col1" >171</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row24_col0" class="data row24 col0" >Stomach</td>
#       <td id="T_041f7_row24_col1" class="data row24 col1" >443</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row25_col0" class="data row25 col0" >Thyroid</td>
#       <td id="T_041f7_row25_col1" class="data row25 col1" >507</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row26_col0" class="data row26 col0" >Chest-Abdomen-Pelvis, Leg, TSpine</td>
#       <td id="T_041f7_row26_col1" class="data row26 col1" >261</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row27_col0" class="data row27 col0" >Cervix</td>
#       <td id="T_041f7_row27_col1" class="data row27 col1" >307</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row28_col0" class="data row28 col0" >Esophagus</td>
#       <td id="T_041f7_row28_col1" class="data row28 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row29_col0" class="data row29 col0" >Adrenal Glands</td>
#       <td id="T_041f7_row29_col1" class="data row29 col1" >271</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row30_col0" class="data row30 col0" >Thymus</td>
#       <td id="T_041f7_row30_col1" class="data row30 col1" >125</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row31_col0" class="data row31 col0" >Ear</td>
#       <td id="T_041f7_row31_col1" class="data row31 col1" >242</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row32_col0" class="data row32 col0" >Marrow, Blood</td>
#       <td id="T_041f7_row32_col1" class="data row32 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row33_col0" class="data row33 col0" >Mesothelium</td>
#       <td id="T_041f7_row33_col1" class="data row33 col1" >87</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row34_col0" class="data row34 col0" >Bile Duct</td>
#       <td id="T_041f7_row34_col1" class="data row34 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row35_col0" class="data row35 col0" >Intraocular</td>
#       <td id="T_041f7_row35_col1" class="data row35 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row36_col0" class="data row36 col0" >Lung Phantom</td>
#       <td id="T_041f7_row36_col1" class="data row36 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row37_col0" class="data row37 col0" >None</td>
#       <td id="T_041f7_row37_col1" class="data row37 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row38_col0" class="data row38 col0" >Pancreas </td>
#       <td id="T_041f7_row38_col1" class="data row38 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_041f7_row39_col0" class="data row39 c

# %% [markdown]
# Probably more common, is to want to filter *out* the empty fields, in which case you use its companion function `IS_NOT`:

# %%
Q('sex IS NOT null').subject.count.run()
# Out:
# Getting results from database
# Total execution time: 3192 ms
#    total : 85654
#   files : 3487816
# <style type="text/css">
# #T_7488f_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7488f_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7488f_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7488f_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_7488f_row0_col1" class="data row0 col1" >84979</td>
#     </tr>
#     <tr>
#       <td id="T_7488f_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_7488f_row1_col1" class="data row1 col1" >2231</td>
#     </tr>
#     <tr>
#       <td id="T_7488f_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_7488f_row2_col1" class="data row2 col1" >11004</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f2582_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f2582_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f2582_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f2582_row0_col0" class="data row0 col0" >female</td>
#       <td id="T_f2582_row0_col1" class="data row0 col1" >45509</td>
#     </tr>
#     <tr>
#       <td id="T_f2582_row1_col0" class="data row1 col0" >male</td>
#       <td id="T_f2582_row1_col1" class="data row1 col1" >39793</td>
#     </tr>
#     <tr>
#       <td id="T_f2582_row2_col0" class="data row2 col0" >not reported</td>
#       <td id="T_f2582_row2_col1" class="data row2 col1" >266</td>
#     </tr>
#     <tr>
#       <td id="T_f2582_row3_col0" class="data row3 col0" >unknown</td>
#       <td id="T_f2582_row3_col1" class="data row3 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_f2582_row4_col0" class="data row4 col0" >unspecified</td>
#       <td id="T_f2582_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d4ffe_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d4ffe_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d4ffe_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >race</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d4ffe_row0_col0" class="data row0 col0" >black or african american</td>
#       <td id="T_d4ffe_row0_col1" class="data row0 col1" >4567</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row1_col0" class="data row1 col0" >white</td>
#       <td id="T_d4ffe_row1_col1" class="data row1 col1" >49069</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row2_col0" class="data row2 col0" >not reported</td>
#       <td id="T_d4ffe_row2_col1" class="data row2 col1" >21816</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row3_col0" class="data row3 col0" >asian</td>
#       <td id="T_d4ffe_row3_col1" class="data row3 col1" >2951</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row4_col0" class="data row4 col0" >chinese</td>
#       <td id="T_d4ffe_row4_col1" class="data row4 col1" >90</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row5_col0" class="data row5 col0" >american indian or alaska native</td>
#       <td id="T_d4ffe_row5_col1" class="data row5 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row6_col0" class="data row6 col0" >Unknown</td>
#       <td id="T_d4ffe_row6_col1" class="data row6 col1" >3985</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row7_col0" class="data row7 col0" >other</td>
#       <td id="T_d4ffe_row7_col1" class="data row7 col1" >947</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row8_col0" class="data row8 col0" >not allowed to collect</td>
#       <td id="T_d4ffe_row8_col1" class="data row8 col1" >2058</td>
#     </tr>
#     <tr>
#       <td id="T_d4ffe_row9_col0" class="data row9 col0" >native hawaiian or other pacific islander</td>
#       <td id="T_d4ffe_row9_col1" class="data row9 col1" >55</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d7846_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d7846_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d7846_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >ethnicity</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d7846_row0_col0" class="data row0 col0" >not hispanic or latino</td>
#       <td id="T_d7846_row0_col1" class="data row0 col1" >48382</td>
#     </tr>
#     <tr>
#       <td id="T_d7846_row1_col0" class="data row1 col0" >not reported</td>
#       <td id="T_d7846_row1_col1" class="data row1 col1" >26034</td>
#     </tr>
#     <tr>
#       <td id="T_d7846_row2_col0" class="data row2 col0" >Unknown</td>
#       <td id="T_d7846_row2_col1" class="data row2 col1" >4455</td>
#     </tr>
#     <tr>
#       <td id="T_d7846_row3_col0" class="data row3 col0" >hispanic or latino</td>
#       <td id="T_d7846_row3_col1" class="data row3 col1" >3131</td>
#     </tr>
#     <tr>
#       <td id="T_d7846_row4_col0" class="data row4 col0" >not allowed to collect</td>
#       <td id="T_d7846_row4_col1" class="data row4 col1" >3652</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_53101_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_53101_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_53101_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >cause_of_death</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53101_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_53101_row0_col1" class="data row0 col1" >84257</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row1_col0" class="data row1 col0" >Not Reported</td>
#       <td id="T_53101_row1_col1" class="data row1 col1" >797</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row2_col0" class="data row2 col0" >HCC recurrence</td>
#       <td id="T_53101_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row3_col0" class="data row3 col0" >Cancer Related</td>
#       <td id="T_53101_row3_col1" class="data row3 col1" >336</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row4_col0" class="data row4 col0" >Unknown</td>
#       <td id="T_53101_row4_col1" class="data row4 col1" >131</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row5_col0" class="data row5 col0" >Cardiovascular Disorder, NOS</td>
#       <td id="T_53101_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row6_col0" class="data row6 col0" >Infection</td>
#       <td id="T_53101_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row7_col0" class="data row7 col0" >Not Cancer Related</td>
#       <td id="T_53101_row7_col1" class="data row7 col1" >107</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row8_col0" class="data row8 col0" >Cancer cell proliferation</td>
#       <td id="T_53101_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row9_col0" class="data row9 col0" >Surgical Complications</td>
#       <td id="T_53101_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row10_col0" class="data row10 col0" >Metastasis</td>
#       <td id="T_53101_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_53101_row11_col0" class="data row11 col0" >Cerebral Hemorrhage</td>
#       <td id="T_53101_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Greater and Less than
#
# While all of the above can also be used to search for numbers, there are four operators that only work for numerical values:
#
# - `>` : Greater than
# - `<` : Less than
# - `>=` : Greater than or Equal to
# - `<=` : Less than or Equal to
#
# These can all be used in place of the `=` sign in queries where you are filtering by a numeric value. In this search, we find all the subjects who were over 50 years old when they entered the study. As the study entry date is day 0, `days_to_birth` is reported as a negative number:

# %%
Q('days_to_birth <= 50*-365 ').specimen.run().to_dataframe()
# Out:
# Getting results from database
# Total execution time: 15098 ms
#                                       id  \
# 0   00c574fc-2d6c-47da-8b45-f4cbadfec86a
# 1   030f905e-f514-5a25-b067-b9ecc0f46cc4
# 2   05b857c3-124e-4b4a-a52d-8a5ea4ee1975
# 3   07845351-b136-4ce9-ac2e-9218adb85194
# 4   08b7411a-a54f-4581-8974-8c913d11a779
# ..                                   ...
# 95  8eca40b3-ebe0-45bb-90d9-2c9c45ce221c
# 96  8fed554b-543a-4aec-8516-16e3e3ee0f1e
# 97  953898f4-51f3-5d82-baa6-eda0f9054b04
# 98  955c38ee-17c5-49a4-9f46-c5a68c0463ed
# 99  957b36c6-7e29-4508-b9bc-679afa85e8ce
#
#                                            identifier associated_project  \
# 0   [{'system': 'GDC', 'value': '00c574fc-2d6c-47d...           TCGA-UCS
# 1   [{'system': 'GDC', 'value': '030f905e-f514-5a2...          TCGA-MESO
# 2   [{'system': 'GDC', 'value': '05b857c3-124e-4b4...          TCGA-PCPG
# 3   [{'system': 'GDC', 'value': '07845351-b136-4ce...           TCGA-UCS
# 4   [{'system': 'GDC', 'value': '08b7411a-a54f-458...          TCGA-PCPG
# ..                                                ...                ...
# 95  [{'system': 'GDC', 'value': '8eca40b3-ebe0-45b...          TCGA-PCPG
# 96  [{'system': 'GDC', 'value': '8fed554b-543a-4ae...           TCGA-UVM
# 97  [{'system': 'GDC', 'value': '953898f4-51f3-5d8...        CTSP-DLBCL1
# 98  [{'system': 'GDC', 'value': '955c38ee-17c5-49a...          HCMI-CMDC
# 99  [{'system': 'GDC', 'value': '957b36c6-7e29-450...           TCGA-UCS
#
#     age_at_collection                 primary_disease_type anatomical_site  \
# 0              -25064  Complex Mixed and Stromal Neoplasms            None
# 1              -22135                Mesothelial Neoplasms            None
# 2              -27311     Paragangliomas and Glomus Tumors            None
# 3              -24823  Complex Mixed and Stromal Neoplasms            None
# 4              -19237     Paragangliomas and Glomus Tumors            None
# ..                ...                                  ...             ...
# 95             -24834     Paragangliomas and Glomus Tumors            None
# 96             -20872                   Nevi and Melanomas            None
# 97             -20786              Mature B-Cell Lymphomas            None
# 98             -26209         Adenomas and Adenocarcinomas            None
# 99             -23323  Complex Mixed and Stromal Neoplasms            None
#
#             source_material_type specimen_type  \
# 0                  Primary Tumor         slide
# 1                  Primary Tumor       portion
# 2                  Primary Tumor       aliquot
# 3                  Primary Tumor       aliquot
# 4                  Primary Tumor       analyte
# ..                           ...           ...
# 95          Blood Derived Normal       portion
# 96                 Primary Tumor        sample
# 97                         Tumor       portion
# 98  Next Generation Cancer Model       analyte
# 99                 Primary Tumor       aliquot
#
#                    derived_from_specimen         subject_id  \
# 0   f30073a4-2ade-5ecb-b69f-52cff561505e       TCGA-N8-A4PN
# 1   5464461d-010f-4713-bc5b-a176601b9218       TCGA-SH-A9CU
# 2   cb3a2587-a3fc-4cd0-8062-2a72d007e123       TCGA-S7-A7WT
# 3   4160f0e5-1cb3-41de-a363-0bbe71b8c174       TCGA-N5-A4RO
# 4   d4999a0b-58ad-435b-993a-4f5bc109ef0b       TCGA-QR-A7IN
# ..                                   ...                ...
# 95  7c86af18-de2e-449f-b675-2b718e3af7e3       TCGA-W2-A7HC
# 96                      initial specimen       TCGA-WC-A87W
# 97  9bfc1e7b-2d48-40f6-bea6-6527c9b42fd7          CTSP-AD14
# 98  d2bffd02-8c71-51f3-846f-6c2c01968921  HCM-CSHL-0238-C18
# 99  5184bfac-8184-4ed7-bee4-127aea0797db       TCGA-NG-A4VU
#
#                       researchsubject_id
# 0   8b7c42cd-fc2a-4023-843e-a411821f94ff
# 1   f544c652-8ee2-4bfe-a42c-41ab4b3697d1
# 2   cc95f915-33e7-4c57-9e6b-4c0e2ba598b2
# 3   4f4906dc-7ebd-47f1-a8f5-b35d3950e740
# 4   dc5c8c56-e3be-4649-8df5-622d497955ce
# ..                                   ...
# 95  da094e20-df07-4efa-892c-33f4ac5c3056
# 96  60d7b6cf-d605-4837-9061-612f6bbb7393
# 97  9b42ae91-9921-48a0-8cac-e6b637804b3d
# 98  67e3c17e-e524-4681-8162-99742c802256
# 99  6db758a1-dd0f-4abb-a0ca-80c4b135e8a5
#
# [100 rows x 11 columns]
