# %% [markdown]
# # Advanced Search with Operators
# ---

# %% [markdown]
# Before we do any work, we need to import several functions from cdapython:
#
#
# - `Q` and `query` which power the search
# - `columns` which lets us view entity field names
# - `unique_terms` which lets view entity field contents
#
# We're also asking cdapython to report it's version so we can be sure we're using the one we mean to.

# %%
from cdapython import Q, columns, unique_terms, query
print(Q.get_version())
Q.set_host_url("http://35.192.60.10:8080/")
# Out:
# 2022.6.21

# %% [markdown]
# The CDA provides a custom python tool for searching CDA data. [`Q`](usage/#q) (short for Query) offers several ways to search and filter data, and several input modes:
#
# ---
# - **[Q.()](../../../Documentation/usage/#q)** builds a query that can be used by `run()` or `count()`
# - **[Q.run()](../../../Documentation/usage/#qrun)** returns data for the specified search
# - **[Q.count()](../../../Documentation/usage/#qcounts)** returns summary information (counts) data that fit the specified search
#
# ---

# %% [markdown]
# Operators allow us to make more complex queries by adding, subtracting, or filtering data.
#
# `Q` uses the following operators:
#
# - [`=` : Equals](#Equals:-=)
# - [`!=` : Not Equal](#Not-Equal:-!=)
# - [`OR`](#OR)
# - [`AND`](#AND)
# - [`IN` and `NOT IN`](#IN-and-NOT-IN)
# - [`%`: pattern matching a wildcard](#%-pattern-matching)
# - [`IS` and `IS NOT`](#IS-and-IS-NOT)
# - [`>`, `>`, `>=`, `<=`: Greater and Less than](#Greater-and-Less-than)
#
#
#
# We use these operators to build more and more complex Q statements before sending our query to `run()` or `count()`.

# %% [markdown]
# ## Equals: `=`
#
# In the other tutorials, we have always used the same query, which uses the `=` operator.
#
# ```Q('ResearchSubject.primary_diagnosis_site = "brain"')```
#
# This operator will only return data where the primary_diagnosis_site is exactly "brain". Here let's to a similar search, but for "uterus". We'll look at the researchsubject summary:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3446 ms
#     total : 867
#    files : 242362
# <style type="text/css">
# #T_3d0d5_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_3d0d5_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_3d0d5_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3d0d5_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_3d0d5_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b2278_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b2278_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b2278_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b2278_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_b2278_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_005df_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_005df_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_005df_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_005df_row0_col0" class="data row0 col0" >Uterus</td>
#       <td id="T_005df_row0_col1" class="data row0 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Not Equal: `!=`
#
# The `!=` operator does the opposite of the `=` operator, it returns everything that is not exactly the term you give it:

# %%
Q('ResearchSubject.primary_diagnosis_site != "uterus"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3180 ms
#    total : 148831
#   files : 39151844
# <style type="text/css">
# #T_4296a_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_4296a_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_4296a_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4296a_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_4296a_row0_col1" class="data row0 col1" >85416</td>
#     </tr>
#     <tr>
#       <td id="T_4296a_row1_col0" class="data row1 col0" >IDC</td>
#       <td id="T_4296a_row1_col1" class="data row1 col1" >61081</td>
#     </tr>
#     <tr>
#       <td id="T_4296a_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_4296a_row2_col1" class="data row2 col1" >2334</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_abe22_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_abe22_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_abe22_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abe22_row0_col0" class="data row0 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_abe22_row0_col1" class="data row0 col1" >3723</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row1_col0" class="data row1 col0" >Gliomas</td>
#       <td id="T_abe22_row1_col1" class="data row1 col1" >4772</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row2_col0" class="data row2 col0" >Ductal and Lobular Neoplasms</td>
#       <td id="T_abe22_row2_col1" class="data row2 col1" >7870</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row3_col0" class="data row3 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_abe22_row3_col1" class="data row3 col1" >32730</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row4_col0" class="data row4 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_abe22_row4_col1" class="data row4 col1" >1826</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row5_col0" class="data row5 col0" >Breast Invasive Carcinoma</td>
#       <td id="T_abe22_row5_col1" class="data row5 col1" >251</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row6_col0" class="data row6 col0" >Nevi and Melanomas</td>
#       <td id="T_abe22_row6_col1" class="data row6 col1" >3155</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row7_col0" class="data row7 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_abe22_row7_col1" class="data row7 col1" >5076</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row8_col0" class="data row8 col0" >Transitional Cell Papillomas and Carcinomas</td>
#       <td id="T_abe22_row8_col1" class="data row8 col1" >1885</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row9_col0" class="data row9 col0" >Plasma Cell Tumors</td>
#       <td id="T_abe22_row9_col1" class="data row9 col1" >1066</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row10_col0" class="data row10 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_abe22_row10_col1" class="data row10 col1" >1332</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row11_col0" class="data row11 col0" >None</td>
#       <td id="T_abe22_row11_col1" class="data row11 col1" >61083</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row12_col0" class="data row12 col0" >Thymic Epithelial Neoplasms</td>
#       <td id="T_abe22_row12_col1" class="data row12 col1" >262</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row13_col0" class="data row13 col0" >Myeloid Leukemias</td>
#       <td id="T_abe22_row13_col1" class="data row13 col1" >3965</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row14_col0" class="data row14 col0" >Synovial-like Neoplasms</td>
#       <td id="T_abe22_row14_col1" class="data row14 col1" >98</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row15_col0" class="data row15 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_abe22_row15_col1" class="data row15 col1" >5694</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row16_col0" class="data row16 col0" >Glioblastoma</td>
#       <td id="T_abe22_row16_col1" class="data row16 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row17_col0" class="data row17 col0" >Other</td>
#       <td id="T_abe22_row17_col1" class="data row17 col1" >206</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row18_col0" class="data row18 col0" >Lymphoid Leukemias</td>
#       <td id="T_abe22_row18_col1" class="data row18 col1" >2072</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row19_col0" class="data row19 col0" >Paragangliomas and Glomus Tumors</td>
#       <td id="T_abe22_row19_col1" class="data row19 col1" >241</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row20_col0" class="data row20 col0" >Colon Adenocarcinoma</td>
#       <td id="T_abe22_row20_col1" class="data row20 col1" >164</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row21_col0" class="data row21 col0" >Lung Squamous Cell Carcinoma</td>
#       <td id="T_abe22_row21_col1" class="data row21 col1" >118</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row22_col0" class="data row22 col0" >Fibromatous Neoplasms</td>
#       <td id="T_abe22_row22_col1" class="data row22 col1" >322</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row23_col0" class="data row23 col0" >Germ Cell Neoplasms</td>
#       <td id="T_abe22_row23_col1" class="data row23 col1" >703</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row24_col0" class="data row24 col0" >Osseous and Chondromatous Neoplasms</td>
#       <td id="T_abe22_row24_col1" class="data row24 col1" >615</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row25_col0" class="data row25 col0" >Mature B-Cell Lymphomas</td>
#       <td id="T_abe22_row25_col1" class="data row25 col1" >1019</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row26_col0" class="data row26 col0" >Lung Adenocarcinoma</td>
#       <td id="T_abe22_row26_col1" class="data row26 col1" >216</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row27_col0" class="data row27 col0" >Specialized Gonadal Neoplasms</td>
#       <td id="T_abe22_row27_col1" class="data row27 col1" >124</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row28_col0" class="data row28 col0" >Mesothelial Neoplasms</td>
#       <td id="T_abe22_row28_col1" class="data row28 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row29_col0" class="data row29 col0" >Myomatous Neoplasms</td>
#       <td id="T_abe22_row29_col1" class="data row29 col1" >632</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row30_col0" class="data row30 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_abe22_row30_col1" class="data row30 col1" >254</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row31_col0" class="data row31 col0" >Pancreatic Ductal Adenocarcinoma</td>
#       <td id="T_abe22_row31_col1" class="data row31 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row32_col0" class="data row32 col0" >Nerve Sheath Tumors</td>
#       <td id="T_abe22_row32_col1" class="data row32 col1" >115</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row33_col0" class="data row33 col0" >Myelodysplastic Syndromes</td>
#       <td id="T_abe22_row33_col1" class="data row33 col1" >386</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row34_col0" class="data row34 col0" >Ovarian Serous Cystadenocarcinoma</td>
#       <td id="T_abe22_row34_col1" class="data row34 col1" >283</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row35_col0" class="data row35 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_abe22_row35_col1" class="data row35 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row36_col0" class="data row36 col0" >Hepatocellular Carcinoma </td>
#       <td id="T_abe22_row36_col1" class="data row36 col1" >170</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row37_col0" class="data row37 col0" >Clear Cell Renal Cell Carcinoma</td>
#       <td id="T_abe22_row37_col1" class="data row37 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_abe22_row38_col0" class="d

# %% [markdown]
# Note that in our `!=` results, there are 1998 "Uterus, NOS" samples. These don't appear in our `=` search because "Uterus, NOS" is not *exactly* "Uterus".
#
# There are several ways to change our search to get both "Uterus" and "Uterus, NOS", and which we choose will depend on both our interests, and on how different the terms are that we care about.

# %% [markdown]
# ## OR
#
# If we have a small enough number of search criteria to reliably type them out, we can use the OR operator to combine results. In an `OR` query, each data point only needs to meet a single piece of criteria to be returned, this makes `OR` good for early, broad searches. It *increases* the amount of data returned.
#
# `OR` can be used both inside a Q statement:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus" OR ResearchSubject.primary_diagnosis_site = "uterus, NOS"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3561 ms
#     total : 2865
#    files : 257140
# <style type="text/css">
# #T_f4c7c_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f4c7c_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f4c7c_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f4c7c_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_f4c7c_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_f4c7c_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_f4c7c_row1_col1" class="data row1 col1" >1894</td>
#     </tr>
#     <tr>
#       <td id="T_f4c7c_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_f4c7c_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_87dee_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_87dee_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_87dee_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87dee_row0_col0" class="data row0 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_87dee_row0_col1" class="data row0 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row1_col0" class="data row1 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_87dee_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row2_col0" class="data row2 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_87dee_row2_col1" class="data row2 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_87dee_row3_col1" class="data row3 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row4_col0" class="data row4 col0" >Myomatous Neoplasms</td>
#       <td id="T_87dee_row4_col1" class="data row4 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row5_col0" class="data row5 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_87dee_row5_col1" class="data row5 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row6_col0" class="data row6 col0" >Not Reported</td>
#       <td id="T_87dee_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row7_col0" class="data row7 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_87dee_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row8_col0" class="data row8 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_87dee_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row9_col0" class="data row9 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_87dee_row9_col1" class="data row9 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row10_col0" class="data row10 col0" >Mesonephromas</td>
#       <td id="T_87dee_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row11_col0" class="data row11 col0" >Trophoblastic neoplasms</td>
#       <td id="T_87dee_row11_col1" class="data row11 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row12_col0" class="data row12 col0" >Neoplasms, NOS</td>
#       <td id="T_87dee_row12_col1" class="data row12 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_87dee_row13_col0" class="data row13 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_87dee_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f521d_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_f521d_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_f521d_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f521d_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_f521d_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_f521d_row1_col0" class="data row1 col0" >Uterus</td>
#       <td id="T_f521d_row1_col1" class="data row1 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# and to combine 2 or more Q statements:

# %%
Query1 = Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS"') 
Query2 = Q('ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"')

Query1.OR(Query2).researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3427 ms
#     total : 1998
#    files : 14778
# <style type="text/css">
# #T_0b1bd_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_0b1bd_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_0b1bd_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b1bd_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_0b1bd_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_0b1bd_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_0b1bd_row1_col1" class="data row1 col1" >1894</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7f8f0_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_7f8f0_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_7f8f0_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f8f0_row0_col0" class="data row0 col0" >Myomatous Neoplasms</td>
#       <td id="T_7f8f0_row0_col1" class="data row0 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row1_col0" class="data row1 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_7f8f0_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row2_col0" class="data row2 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_7f8f0_row2_col1" class="data row2 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row3_col0" class="data row3 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_7f8f0_row3_col1" class="data row3 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row4_col0" class="data row4 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_7f8f0_row4_col1" class="data row4 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row5_col0" class="data row5 col0" >Not Reported</td>
#       <td id="T_7f8f0_row5_col1" class="data row5 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row6_col0" class="data row6 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_7f8f0_row6_col1" class="data row6 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row7_col0" class="data row7 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_7f8f0_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row8_col0" class="data row8 col0" >Trophoblastic neoplasms</td>
#       <td id="T_7f8f0_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row9_col0" class="data row9 col0" >Neoplasms, NOS</td>
#       <td id="T_7f8f0_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row10_col0" class="data row10 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_7f8f0_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row11_col0" class="data row11 col0" >Mesonephromas</td>
#       <td id="T_7f8f0_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_7f8f0_row12_col0" class="data row12 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_7f8f0_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6d4d4_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_6d4d4_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_6d4d4_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d4d4_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_6d4d4_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For each `OR` you must specify both the search term ("uterus") and where to find the term ("ResearchSubject.primary_diagnosis_site"). This means that the `OR` operator is flexible enough to run searches across columns, or even across endpoints.

# %% [markdown]
# ## AND
#
# Like `OR`, `AND` can be used both inside a Q statement, and to join multiple Q statements. `AND` requires that both statements be true simultanously for each returned bit of data. This makes `AND` good for filtering down results. It *decreases* the amount of data returned.
#
# If we reuse the `OR` examples above, the first one will have no results, because primary_diagnosis_site can have only one value, so it can never be both "uterus" and "uterus, NOS":

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus" AND ResearchSubject.primary_diagnosis_site = "uterus, NOS"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3702 ms
#      total : 0
#      files : 0
# <style type="text/css">
# #T_cd490_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_cd490_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_cd490_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b04fb_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b04fb_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b04fb_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6ca65_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_6ca65_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_6ca65_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# However, for searches where you are interested in subsetting multiple columns, `AND` can help you to quickly filter to only the set you want. Note that `AND` can be used both inside a `Q` statement, and to add multiple `Q` statements together:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS" AND ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3281 ms
#     total : 104
#     files : 2560
# <style type="text/css">
# #T_ac74f_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_ac74f_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_ac74f_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac74f_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_ac74f_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5e292_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_5e292_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_5e292_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e292_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_5e292_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c1f3c_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_c1f3c_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_c1f3c_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1f3c_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_c1f3c_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>

# %%
Query1 = Q('ResearchSubject.primary_diagnosis_site = "uterus, NOS"') 
Query2 = Q('ResearchSubject.primary_diagnosis_condition = "Uterine Corpus Endometrial Carcinoma"')

Query1.AND(Query2).researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3419 ms
#     total : 104
#     files : 2560
# <style type="text/css">
# #T_750d1_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_750d1_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_750d1_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_750d1_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_750d1_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9b518_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_9b518_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_9b518_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b518_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_9b518_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4fe39_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_4fe39_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_4fe39_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4fe39_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_4fe39_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `IN` and `NOT IN`
#
# For instances where you have many search terms, it may be easier (and more readable) to use `IN`. With `IN` you make a list of all the terms you are interested in, and ask whether they are `IN` a given field:

# %%
Q('ResearchSubject.primary_diagnosis_site IN ("uterus, NOS", "uterus", "Cervix", "Cervix uteri")').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3391 ms
#     total : 4087
#    files : 299493
# <style type="text/css">
# #T_6a76b_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_6a76b_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_6a76b_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6a76b_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_6a76b_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_6a76b_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_6a76b_row1_col1" class="data row1 col1" >2809</td>
#     </tr>
#     <tr>
#       <td id="T_6a76b_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_6a76b_row2_col1" class="data row2 col1" >1174</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_711ca_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_711ca_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_711ca_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_711ca_row0_col0" class="data row0 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_711ca_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row1_col0" class="data row1 col0" >Myomatous Neoplasms</td>
#       <td id="T_711ca_row1_col1" class="data row1 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row2_col0" class="data row2 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_711ca_row2_col1" class="data row2 col1" >1264</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row3_col0" class="data row3 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_711ca_row3_col1" class="data row3 col1" >609</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row4_col0" class="data row4 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_711ca_row4_col1" class="data row4 col1" >348</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row5_col0" class="data row5 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_711ca_row5_col1" class="data row5 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row6_col0" class="data row6 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_711ca_row6_col1" class="data row6 col1" >27</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_711ca_row7_col1" class="data row7 col1" >1175</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row8_col0" class="data row8 col0" >Not Reported</td>
#       <td id="T_711ca_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row9_col0" class="data row9 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_711ca_row9_col1" class="data row9 col1" >26</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row10_col0" class="data row10 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_711ca_row10_col1" class="data row10 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row11_col0" class="data row11 col0" >Neoplasms, NOS</td>
#       <td id="T_711ca_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row12_col0" class="data row12 col0" >Trophoblastic neoplasms</td>
#       <td id="T_711ca_row12_col1" class="data row12 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row13_col0" class="data row13 col0" >Mesonephromas</td>
#       <td id="T_711ca_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_711ca_row14_col0" class="data row14 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_711ca_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_44b2d_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_44b2d_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_44b2d_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44b2d_row0_col0" class="data row0 col0" >Cervix uteri</td>
#       <td id="T_44b2d_row0_col1" class="data row0 col1" >915</td>
#     </tr>
#     <tr>
#       <td id="T_44b2d_row1_col0" class="data row1 col0" >Uterus, NOS</td>
#       <td id="T_44b2d_row1_col1" class="data row1 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_44b2d_row2_col0" class="data row2 col0" >Uterus</td>
#       <td id="T_44b2d_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_44b2d_row3_col0" class="data row3 col0" >Cervix</td>
#       <td id="T_44b2d_row3_col1" class="data row3 col1" >307</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The equivilent request without `IN` would require a large number of `OR` statements. (The triple quotes surrounding this example are to allow a multi-line Q statement):
#
# ``` py
# Q("""ResearchSubject.primary_diagnosis_site = "uterus, NOS" OR
#       ResearchSubject.primary_diagnosis_site = "uterus" OR
#       ResearchSubject.primary_diagnosis_site = "Cervix" OR
#       ResearchSubject.primary_diagnosis_site = "Cervix uteri" """).researchsubject.count.run()
#
# ```

# %% [markdown]
# `NOT IN` is the opposite of `IN`, and so gives the inverse results. If we add `NOT` to our above query, we get all the researchsubjecst who's primary_diagnosis_site was not in our list:

# %%
Q('ResearchSubject.primary_diagnosis_site NOT IN ("uterus, NOS", "uterus", "Cervix", "Cervix uteri")').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3483 ms
#    total : 145611
#   files : 39097313
# <style type="text/css">
# #T_3590a_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_3590a_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_3590a_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3590a_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_3590a_row0_col1" class="data row0 col1" >82607</td>
#     </tr>
#     <tr>
#       <td id="T_3590a_row1_col0" class="data row1 col0" >IDC</td>
#       <td id="T_3590a_row1_col1" class="data row1 col1" >60774</td>
#     </tr>
#     <tr>
#       <td id="T_3590a_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_3590a_row2_col1" class="data row2 col1" >2230</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2fbd3_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_2fbd3_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_2fbd3_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2fbd3_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_2fbd3_row0_col1" class="data row0 col1" >31466</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row1_col0" class="data row1 col0" >Other</td>
#       <td id="T_2fbd3_row1_col1" class="data row1 col1" >206</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row2_col0" class="data row2 col0" >Ductal and Lobular Neoplasms</td>
#       <td id="T_2fbd3_row2_col1" class="data row2 col1" >7870</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_2fbd3_row3_col1" class="data row3 col1" >60775</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row4_col0" class="data row4 col0" >Plasma Cell Tumors</td>
#       <td id="T_2fbd3_row4_col1" class="data row4 col1" >1066</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row5_col0" class="data row5 col0" >Lymphoid Leukemias</td>
#       <td id="T_2fbd3_row5_col1" class="data row5 col1" >2072</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row6_col0" class="data row6 col0" >Myeloid Leukemias</td>
#       <td id="T_2fbd3_row6_col1" class="data row6 col1" >3965</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row7_col0" class="data row7 col0" >Nevi and Melanomas</td>
#       <td id="T_2fbd3_row7_col1" class="data row7 col1" >3155</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row8_col0" class="data row8 col0" >Pancreatic Ductal Adenocarcinoma</td>
#       <td id="T_2fbd3_row8_col1" class="data row8 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row9_col0" class="data row9 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_2fbd3_row9_col1" class="data row9 col1" >1331</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row10_col0" class="data row10 col0" >Myomatous Neoplasms</td>
#       <td id="T_2fbd3_row10_col1" class="data row10 col1" >449</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row11_col0" class="data row11 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_2fbd3_row11_col1" class="data row11 col1" >4467</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row12_col0" class="data row12 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_2fbd3_row12_col1" class="data row12 col1" >5668</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row13_col0" class="data row13 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_2fbd3_row13_col1" class="data row13 col1" >3375</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row14_col0" class="data row14 col0" >Transitional Cell Papillomas and Carcinomas</td>
#       <td id="T_2fbd3_row14_col1" class="data row14 col1" >1885</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row15_col0" class="data row15 col0" >Miscellaneous Tumors</td>
#       <td id="T_2fbd3_row15_col1" class="data row15 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row16_col0" class="data row16 col0" >Gliomas</td>
#       <td id="T_2fbd3_row16_col1" class="data row16 col1" >4772</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row17_col0" class="data row17 col0" >Mesothelial Neoplasms</td>
#       <td id="T_2fbd3_row17_col1" class="data row17 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row18_col0" class="data row18 col0" >Glioblastoma</td>
#       <td id="T_2fbd3_row18_col1" class="data row18 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row19_col0" class="data row19 col0" >Fibromatous Neoplasms</td>
#       <td id="T_2fbd3_row19_col1" class="data row19 col1" >322</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row20_col0" class="data row20 col0" >Meningiomas</td>
#       <td id="T_2fbd3_row20_col1" class="data row20 col1" >289</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row21_col0" class="data row21 col0" >Thymic Epithelial Neoplasms</td>
#       <td id="T_2fbd3_row21_col1" class="data row21 col1" >262</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row22_col0" class="data row22 col0" >Clear Cell Renal Cell Carcinoma</td>
#       <td id="T_2fbd3_row22_col1" class="data row22 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row23_col0" class="data row23 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_2fbd3_row23_col1" class="data row23 col1" >1532</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row24_col0" class="data row24 col0" >Mature B-Cell Lymphomas</td>
#       <td id="T_2fbd3_row24_col1" class="data row24 col1" >1019</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row25_col0" class="data row25 col0" >Germ Cell Neoplasms</td>
#       <td id="T_2fbd3_row25_col1" class="data row25 col1" >703</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row26_col0" class="data row26 col0" >Lung Squamous Cell Carcinoma</td>
#       <td id="T_2fbd3_row26_col1" class="data row26 col1" >118</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row27_col0" class="data row27 col0" >Lung Adenocarcinoma</td>
#       <td id="T_2fbd3_row27_col1" class="data row27 col1" >216</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row28_col0" class="data row28 col0" >Colon Adenocarcinoma</td>
#       <td id="T_2fbd3_row28_col1" class="data row28 col1" >164</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row29_col0" class="data row29 col0" >Nerve Sheath Tumors</td>
#       <td id="T_2fbd3_row29_col1" class="data row29 col1" >115</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row30_col0" class="data row30 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_2fbd3_row30_col1" class="data row30 col1" >227</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row31_col0" class="data row31 col0" >Lipomatous Neoplasms</td>
#       <td id="T_2fbd3_row31_col1" class="data row31 col1" >343</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row32_col0" class="data row32 col0" >Breast Invasive Carcinoma</td>
#       <td id="T_2fbd3_row32_col1" class="data row32 col1" >251</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row33_col0" class="data row33 col0" >Osseous and Chondromatous Neoplasms</td>
#       <td id="T_2fbd3_row33_col1" class="data row33 col1" >615</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row34_col0" class="data row34 col0" >Oral Squamous Cell Carcinoma</td>
#       <td id="T_2fbd3_row34_col1" class="data row34 col1" >38</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row35_col0" class="data row35 col0" >Paragangliomas and Glomus Tumors</td>
#       <td id="T_2fbd3_row35_col1" class="data row35 col1" >241</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row36_col0" class="data row36 col0" >Ovarian Serous Cystadenocarcinoma</td>
#       <td id="T_2fbd3_row36_col1" class="data row36 col1" >283</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row37_col0" class="data row37 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_2fbd3_row37_col1" class="data row37 col1" >301</td>
#     </tr>
#     <tr>
#       <td id="T_2fbd3_row38_col0" class="data row38 col0" >Hepatoc

# %% [markdown]
# ## `%` pattern matching
#
# While `OR` is useful for situations with only a few options, in some cases there are many terms that all have similar names, and it would be error prone to type out every variant. For instance, if we filter the unique terms in "ResearchSubject.primary_diagnosis_site" to everything with "uter" we get:

# %%
unique_terms("ResearchSubject.primary_diagnosis_site").to_list(filters="uter")
# Out:
# ['Cervix uteri', 'Corpus uteri', 'Uterus', 'Uterus, NOS']

# %% [markdown]
# The `%` operator acts as a wildcard, and lets you run a query similar to the filter function in unique_terms:

# %%
Q('ResearchSubject.primary_diagnosis_site = "uter%"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3317 ms
#     total : 2865
#    files : 257140
# <style type="text/css">
# #T_9e0ac_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_9e0ac_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_9e0ac_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e0ac_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_9e0ac_row0_col1" class="data row0 col1" >1894</td>
#     </tr>
#     <tr>
#       <td id="T_9e0ac_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_9e0ac_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_9e0ac_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_9e0ac_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_72321_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_72321_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_72321_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_72321_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_72321_row0_col1" class="data row0 col1" >1037</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row1_col0" class="data row1 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_72321_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row2_col0" class="data row2 col0" >Not Reported</td>
#       <td id="T_72321_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row3_col0" class="data row3 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_72321_row3_col1" class="data row3 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row4_col0" class="data row4 col0" >Myomatous Neoplasms</td>
#       <td id="T_72321_row4_col1" class="data row4 col1" >183</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_72321_row5_col1" class="data row5 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row6_col0" class="data row6 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_72321_row6_col1" class="data row6 col1" >313</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row7_col0" class="data row7 col0" >Trophoblastic neoplasms</td>
#       <td id="T_72321_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row8_col0" class="data row8 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_72321_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row9_col0" class="data row9 col0" >Mesonephromas</td>
#       <td id="T_72321_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row10_col0" class="data row10 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_72321_row10_col1" class="data row10 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row11_col0" class="data row11 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_72321_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row12_col0" class="data row12 col0" >Neoplasms, NOS</td>
#       <td id="T_72321_row12_col1" class="data row12 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_72321_row13_col0" class="data row13 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_72321_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b3484_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b3484_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b3484_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b3484_row0_col0" class="data row0 col0" >Uterus, NOS</td>
#       <td id="T_b3484_row0_col1" class="data row0 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_b3484_row1_col0" class="data row1 col0" >Uterus</td>
#       <td id="T_b3484_row1_col1" class="data row1 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Because the `%` is at the end of "uter" this query returns anything that starts with "uter", depending on your question, you may want to move the `%`, or add more of them:

# %%
Q('ResearchSubject.primary_diagnosis_site = "%uter"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3325 ms
#      total : 0
#      files : 0
# <style type="text/css">
# #T_64dd7_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_64dd7_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_64dd7_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_54065_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_54065_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_54065_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_27f20_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_27f20_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_27f20_" style='display:inline'>
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
Q('ResearchSubject.primary_diagnosis_site = "%uter%"').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3252 ms
#     total : 4560
#    files : 302149
# <style type="text/css">
# #T_8f16d_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_8f16d_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_8f16d_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8f16d_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_8f16d_row0_col1" class="data row0 col1" >3589</td>
#     </tr>
#     <tr>
#       <td id="T_8f16d_row1_col0" class="data row1 col0" >PDC</td>
#       <td id="T_8f16d_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_8f16d_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_8f16d_row2_col1" class="data row2 col1" >867</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_81c67_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_81c67_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_81c67_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81c67_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_81c67_row0_col1" class="data row0 col1" >1671</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row1_col0" class="data row1 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_81c67_row1_col1" class="data row1 col1" >487</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row2_col0" class="data row2 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_81c67_row2_col1" class="data row2 col1" >609</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row3_col0" class="data row3 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_81c67_row3_col1" class="data row3 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row4_col0" class="data row4 col0" >Myomatous Neoplasms</td>
#       <td id="T_81c67_row4_col1" class="data row4 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row5_col0" class="data row5 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_81c67_row5_col1" class="data row5 col1" >320</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_81c67_row6_col1" class="data row6 col1" >868</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row7_col0" class="data row7 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_81c67_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row8_col0" class="data row8 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_81c67_row8_col1" class="data row8 col1" >230</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row9_col0" class="data row9 col0" >Not Reported</td>
#       <td id="T_81c67_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row10_col0" class="data row10 col0" >Trophoblastic neoplasms</td>
#       <td id="T_81c67_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row11_col0" class="data row11 col0" >Neoplasms, NOS</td>
#       <td id="T_81c67_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row12_col0" class="data row12 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_81c67_row12_col1" class="data row12 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row13_col0" class="data row13 col0" >Mesonephromas</td>
#       <td id="T_81c67_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_81c67_row14_col0" class="data row14 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_81c67_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9f1ca_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_9f1ca_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_9f1ca_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9f1ca_row0_col0" class="data row0 col0" >Corpus uteri</td>
#       <td id="T_9f1ca_row0_col1" class="data row0 col1" >780</td>
#     </tr>
#     <tr>
#       <td id="T_9f1ca_row1_col0" class="data row1 col0" >Cervix uteri</td>
#       <td id="T_9f1ca_row1_col1" class="data row1 col1" >915</td>
#     </tr>
#     <tr>
#       <td id="T_9f1ca_row2_col0" class="data row2 col0" >Uterus, NOS</td>
#       <td id="T_9f1ca_row2_col1" class="data row2 col1" >1998</td>
#     </tr>
#     <tr>
#       <td id="T_9f1ca_row3_col0" class="data row3 col0" >Uterus</td>
#       <td id="T_9f1ca_row3_col1" class="data row3 col1" >867</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There may be cases in which you want to filter out all of the data with some partial word in it, in which case, you can combine `%` with `!=`:

# %%
Q('sex != "f%"').subject.count.run()
# Out:
# Getting results from database
# Total execution time: 3267 ms
#    total : 91361
#   files : 37815169
# <style type="text/css">
# #T_64601_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_64601_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_64601_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_64601_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_64601_row0_col1" class="data row0 col1" >56038</td>
#     </tr>
#     <tr>
#       <td id="T_64601_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_64601_row1_col1" class="data row1 col1" >40024</td>
#     </tr>
#     <tr>
#       <td id="T_64601_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_64601_row2_col1" class="data row2 col1" >1089</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2d276_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_2d276_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_2d276_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d276_row0_col0" class="data row0 col0" >not reported</td>
#       <td id="T_2d276_row0_col1" class="data row0 col1" >266</td>
#     </tr>
#     <tr>
#       <td id="T_2d276_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_2d276_row1_col1" class="data row1 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_2d276_row2_col0" class="data row2 col0" >male</td>
#       <td id="T_2d276_row2_col1" class="data row2 col1" >39793</td>
#     </tr>
#     <tr>
#       <td id="T_2d276_row3_col0" class="data row3 col0" >unknown</td>
#       <td id="T_2d276_row3_col1" class="data row3 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_2d276_row4_col0" class="data row4 col0" >unspecified</td>
#       <td id="T_2d276_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_29cdb_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_29cdb_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_29cdb_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >race</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_29cdb_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_29cdb_row0_col1" class="data row0 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row1_col0" class="data row1 col0" >white</td>
#       <td id="T_29cdb_row1_col1" class="data row1 col1" >23406</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row2_col0" class="data row2 col0" >chinese</td>
#       <td id="T_29cdb_row2_col1" class="data row2 col1" >65</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row3_col0" class="data row3 col0" >asian</td>
#       <td id="T_29cdb_row3_col1" class="data row3 col1" >1348</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row4_col0" class="data row4 col0" >black or african american</td>
#       <td id="T_29cdb_row4_col1" class="data row4 col1" >1815</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row5_col0" class="data row5 col0" >not reported</td>
#       <td id="T_29cdb_row5_col1" class="data row5 col1" >9881</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row6_col0" class="data row6 col0" >not allowed to collect</td>
#       <td id="T_29cdb_row6_col1" class="data row6 col1" >1106</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row7_col0" class="data row7 col0" >other</td>
#       <td id="T_29cdb_row7_col1" class="data row7 col1" >415</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row8_col0" class="data row8 col0" >Unknown</td>
#       <td id="T_29cdb_row8_col1" class="data row8 col1" >2027</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row9_col0" class="data row9 col0" >american indian or alaska native</td>
#       <td id="T_29cdb_row9_col1" class="data row9 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_29cdb_row10_col0" class="data row10 col0" >native hawaiian or other pacific islander</td>
#       <td id="T_29cdb_row10_col1" class="data row10 col1" >26</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fef18_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_fef18_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_fef18_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >ethnicity</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fef18_row0_col0" class="data row0 col0" >not reported</td>
#       <td id="T_fef18_row0_col1" class="data row0 col1" >11796</td>
#     </tr>
#     <tr>
#       <td id="T_fef18_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_fef18_row1_col1" class="data row1 col1" >51216</td>
#     </tr>
#     <tr>
#       <td id="T_fef18_row2_col0" class="data row2 col0" >not hispanic or latino</td>
#       <td id="T_fef18_row2_col1" class="data row2 col1" >23020</td>
#     </tr>
#     <tr>
#       <td id="T_fef18_row3_col0" class="data row3 col0" >Unknown</td>
#       <td id="T_fef18_row3_col1" class="data row3 col1" >2293</td>
#     </tr>
#     <tr>
#       <td id="T_fef18_row4_col0" class="data row4 col0" >hispanic or latino</td>
#       <td id="T_fef18_row4_col1" class="data row4 col1" >1450</td>
#     </tr>
#     <tr>
#       <td id="T_fef18_row5_col0" class="data row5 col0" >not allowed to collect</td>
#       <td id="T_fef18_row5_col1" class="data row5 col1" >1586</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c2973_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_c2973_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_c2973_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >cause_of_death</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c2973_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_c2973_row0_col1" class="data row0 col1" >90714</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row1_col0" class="data row1 col0" >Not Reported</td>
#       <td id="T_c2973_row1_col1" class="data row1 col1" >335</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row2_col0" class="data row2 col0" >Metastasis</td>
#       <td id="T_c2973_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row3_col0" class="data row3 col0" >Infection</td>
#       <td id="T_c2973_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row4_col0" class="data row4 col0" >Cancer Related</td>
#       <td id="T_c2973_row4_col1" class="data row4 col1" >198</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row5_col0" class="data row5 col0" >Unknown</td>
#       <td id="T_c2973_row5_col1" class="data row5 col1" >22</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row6_col0" class="data row6 col0" >Not Cancer Related</td>
#       <td id="T_c2973_row6_col1" class="data row6 col1" >76</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row7_col0" class="data row7 col0" >HCC recurrence</td>
#       <td id="T_c2973_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row8_col0" class="data row8 col0" >Surgical Complications</td>
#       <td id="T_c2973_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row9_col0" class="data row9 col0" >Cardiovascular Disorder, NOS</td>
#       <td id="T_c2973_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_c2973_row10_col0" class="data row10 col0" >Cerebral Hemorrhage</td>
#       <td id="T_c2973_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## IS and IS NOT
#
# In computing, lack of data is often treated as a special case. In the CDA, values listed as "None" are actually `null`, that is, the field is empty. In order to search for emptiness, you need to use the special function `IS`:

# %%
Q('ResearchSubject.primary_diagnosis_condition IS null').researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 3273 ms
#    total : 61950
#   files : 38475829
# <style type="text/css">
# #T_b1f50_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b1f50_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b1f50_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1f50_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_b1f50_row0_col1" class="data row0 col1" >61948</td>
#     </tr>
#     <tr>
#       <td id="T_b1f50_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_b1f50_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_739c3_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_739c3_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_739c3_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_739c3_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_739c3_row0_col1" class="data row0 col1" >61950</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ffa94_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_ffa94_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_ffa94_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ffa94_row0_col0" class="data row0 col0" >Breast</td>
#       <td id="T_ffa94_row0_col1" class="data row0 col1" >12587</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row1_col0" class="data row1 col0" >Head-Neck</td>
#       <td id="T_ffa94_row1_col1" class="data row1 col1" >2704</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row2_col0" class="data row2 col0" >Colon</td>
#       <td id="T_ffa94_row2_col1" class="data row2 col1" >1491</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row3_col0" class="data row3 col0" >Chest</td>
#       <td id="T_ffa94_row3_col1" class="data row3 col1" >28221</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row4_col0" class="data row4 col0" >Lung</td>
#       <td id="T_ffa94_row4_col1" class="data row4 col1" >4728</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row5_col0" class="data row5 col0" >Abdomen</td>
#       <td id="T_ffa94_row5_col1" class="data row5 col1" >92</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row6_col0" class="data row6 col0" >Various</td>
#       <td id="T_ffa94_row6_col1" class="data row6 col1" >449</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row7_col0" class="data row7 col0" >Brain</td>
#       <td id="T_ffa94_row7_col1" class="data row7 col1" >1165</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row8_col0" class="data row8 col0" >Abdomen, Mediastinum</td>
#       <td id="T_ffa94_row8_col1" class="data row8 col1" >176</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row9_col0" class="data row9 col0" >Thymus</td>
#       <td id="T_ffa94_row9_col1" class="data row9 col1" >125</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row10_col0" class="data row10 col0" >Bladder</td>
#       <td id="T_ffa94_row10_col1" class="data row10 col1" >431</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row11_col0" class="data row11 col0" >Kidney</td>
#       <td id="T_ffa94_row11_col1" class="data row11 col1" >1373</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row12_col0" class="data row12 col0" >Uterus</td>
#       <td id="T_ffa94_row12_col1" class="data row12 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row13_col0" class="data row13 col0" >Various (11 locations)</td>
#       <td id="T_ffa94_row13_col1" class="data row13 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row14_col0" class="data row14 col0" >Pancreas</td>
#       <td id="T_ffa94_row14_col1" class="data row14 col1" >481</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row15_col0" class="data row15 col0" >Skin</td>
#       <td id="T_ffa94_row15_col1" class="data row15 col1" >612</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row16_col0" class="data row16 col0" >Head</td>
#       <td id="T_ffa94_row16_col1" class="data row16 col1" >105</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row17_col0" class="data row17 col0" >Liver</td>
#       <td id="T_ffa94_row17_col1" class="data row17 col1" >452</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row18_col0" class="data row18 col0" >Prostate</td>
#       <td id="T_ffa94_row18_col1" class="data row18 col1" >2139</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row19_col0" class="data row19 col0" >Pelvis, Prostate, Anus</td>
#       <td id="T_ffa94_row19_col1" class="data row19 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row20_col0" class="data row20 col0" >Phantom</td>
#       <td id="T_ffa94_row20_col1" class="data row20 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row21_col0" class="data row21 col0" >Extremities</td>
#       <td id="T_ffa94_row21_col1" class="data row21 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row22_col0" class="data row22 col0" >Ovary</td>
#       <td id="T_ffa94_row22_col1" class="data row22 col1" >664</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row23_col0" class="data row23 col0" >Testicles</td>
#       <td id="T_ffa94_row23_col1" class="data row23 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row24_col0" class="data row24 col0" >Bile Duct</td>
#       <td id="T_ffa94_row24_col1" class="data row24 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row25_col0" class="data row25 col0" >Rectum</td>
#       <td id="T_ffa94_row25_col1" class="data row25 col1" >171</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row26_col0" class="data row26 col0" >Thyroid</td>
#       <td id="T_ffa94_row26_col1" class="data row26 col1" >507</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row27_col0" class="data row27 col0" >Stomach</td>
#       <td id="T_ffa94_row27_col1" class="data row27 col1" >443</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row28_col0" class="data row28 col0" >Chest-Abdomen-Pelvis, Leg, TSpine</td>
#       <td id="T_ffa94_row28_col1" class="data row28 col1" >261</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row29_col0" class="data row29 col0" >Mesothelium</td>
#       <td id="T_ffa94_row29_col1" class="data row29 col1" >87</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row30_col0" class="data row30 col0" >Adrenal Glands</td>
#       <td id="T_ffa94_row30_col1" class="data row30 col1" >271</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row31_col0" class="data row31 col0" >Esophagus</td>
#       <td id="T_ffa94_row31_col1" class="data row31 col1" >187</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row32_col0" class="data row32 col0" >Cervix</td>
#       <td id="T_ffa94_row32_col1" class="data row32 col1" >307</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row33_col0" class="data row33 col0" >Ear</td>
#       <td id="T_ffa94_row33_col1" class="data row33 col1" >242</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row34_col0" class="data row34 col0" >Marrow, Blood</td>
#       <td id="T_ffa94_row34_col1" class="data row34 col1" >89</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row35_col0" class="data row35 col0" >Intraocular</td>
#       <td id="T_ffa94_row35_col1" class="data row35 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row36_col0" class="data row36 col0" >Cervix uteri</td>
#       <td id="T_ffa94_row36_col1" class="data row36 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row37_col0" class="data row37 col0" >Lung Phantom</td>
#       <td id="T_ffa94_row37_col1" class="data row37 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row38_col0" class="data row38 col0" >Pancreas </td>
#       <td id="T_ffa94_row38_col1" class="data row38 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ffa94_row39_col0" class="data

# %% [markdown]
# Probably more common, is to want to filter *out* the empty fields, in which case you use its companion function `IS_NOT`:

# %%
Q('sex IS NOT null').subject.count.run()
# Out:
# Getting results from database
# Total execution time: 3201 ms
#    total : 85654
#   files : 3487816
# <style type="text/css">
# #T_3aca9_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_3aca9_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_3aca9_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3aca9_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_3aca9_row0_col1" class="data row0 col1" >84979</td>
#     </tr>
#     <tr>
#       <td id="T_3aca9_row1_col0" class="data row1 col0" >IDC</td>
#       <td id="T_3aca9_row1_col1" class="data row1 col1" >11004</td>
#     </tr>
#     <tr>
#       <td id="T_3aca9_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_3aca9_row2_col1" class="data row2 col1" >2231</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a9a4f_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_a9a4f_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_a9a4f_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9a4f_row0_col0" class="data row0 col0" >female</td>
#       <td id="T_a9a4f_row0_col1" class="data row0 col1" >45509</td>
#     </tr>
#     <tr>
#       <td id="T_a9a4f_row1_col0" class="data row1 col0" >not reported</td>
#       <td id="T_a9a4f_row1_col1" class="data row1 col1" >266</td>
#     </tr>
#     <tr>
#       <td id="T_a9a4f_row2_col0" class="data row2 col0" >male</td>
#       <td id="T_a9a4f_row2_col1" class="data row2 col1" >39793</td>
#     </tr>
#     <tr>
#       <td id="T_a9a4f_row3_col0" class="data row3 col0" >unknown</td>
#       <td id="T_a9a4f_row3_col1" class="data row3 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_a9a4f_row4_col0" class="data row4 col0" >unspecified</td>
#       <td id="T_a9a4f_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_634b6_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_634b6_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_634b6_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >race</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_634b6_row0_col0" class="data row0 col0" >black or african american</td>
#       <td id="T_634b6_row0_col1" class="data row0 col1" >4567</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row1_col0" class="data row1 col0" >white</td>
#       <td id="T_634b6_row1_col1" class="data row1 col1" >49069</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row2_col0" class="data row2 col0" >not reported</td>
#       <td id="T_634b6_row2_col1" class="data row2 col1" >21816</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row3_col0" class="data row3 col0" >chinese</td>
#       <td id="T_634b6_row3_col1" class="data row3 col1" >90</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row4_col0" class="data row4 col0" >asian</td>
#       <td id="T_634b6_row4_col1" class="data row4 col1" >2951</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row5_col0" class="data row5 col0" >Unknown</td>
#       <td id="T_634b6_row5_col1" class="data row5 col1" >3985</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row6_col0" class="data row6 col0" >native hawaiian or other pacific islander</td>
#       <td id="T_634b6_row6_col1" class="data row6 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row7_col0" class="data row7 col0" >other</td>
#       <td id="T_634b6_row7_col1" class="data row7 col1" >947</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row8_col0" class="data row8 col0" >american indian or alaska native</td>
#       <td id="T_634b6_row8_col1" class="data row8 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_634b6_row9_col0" class="data row9 col0" >not allowed to collect</td>
#       <td id="T_634b6_row9_col1" class="data row9 col1" >2058</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a8588_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_a8588_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_a8588_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >ethnicity</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a8588_row0_col0" class="data row0 col0" >not hispanic or latino</td>
#       <td id="T_a8588_row0_col1" class="data row0 col1" >48382</td>
#     </tr>
#     <tr>
#       <td id="T_a8588_row1_col0" class="data row1 col0" >not reported</td>
#       <td id="T_a8588_row1_col1" class="data row1 col1" >26034</td>
#     </tr>
#     <tr>
#       <td id="T_a8588_row2_col0" class="data row2 col0" >Unknown</td>
#       <td id="T_a8588_row2_col1" class="data row2 col1" >4455</td>
#     </tr>
#     <tr>
#       <td id="T_a8588_row3_col0" class="data row3 col0" >hispanic or latino</td>
#       <td id="T_a8588_row3_col1" class="data row3 col1" >3131</td>
#     </tr>
#     <tr>
#       <td id="T_a8588_row4_col0" class="data row4 col0" >not allowed to collect</td>
#       <td id="T_a8588_row4_col1" class="data row4 col1" >3652</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d247b_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d247b_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d247b_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >cause_of_death</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d247b_row0_col0" class="data row0 col0" >Not Reported</td>
#       <td id="T_d247b_row0_col1" class="data row0 col1" >797</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_d247b_row1_col1" class="data row1 col1" >84257</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row2_col0" class="data row2 col0" >HCC recurrence</td>
#       <td id="T_d247b_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row3_col0" class="data row3 col0" >Cancer Related</td>
#       <td id="T_d247b_row3_col1" class="data row3 col1" >336</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row4_col0" class="data row4 col0" >Unknown</td>
#       <td id="T_d247b_row4_col1" class="data row4 col1" >131</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row5_col0" class="data row5 col0" >Infection</td>
#       <td id="T_d247b_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row6_col0" class="data row6 col0" >Not Cancer Related</td>
#       <td id="T_d247b_row6_col1" class="data row6 col1" >107</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row7_col0" class="data row7 col0" >Surgical Complications</td>
#       <td id="T_d247b_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row8_col0" class="data row8 col0" >Cardiovascular Disorder, NOS</td>
#       <td id="T_d247b_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row9_col0" class="data row9 col0" >Cancer cell proliferation</td>
#       <td id="T_d247b_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row10_col0" class="data row10 col0" >Metastasis</td>
#       <td id="T_d247b_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_d247b_row11_col0" class="data row11 col0" >Cerebral Hemorrhage</td>
#       <td id="T_d247b_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Greater and Less than
#
# While all of the above can also be used to search for numbers, there are four operators that only work for numerical values:
#
# - `>` : Greater than
# - `<` : Less than
# - `>=` : Greater than or Equal to
# - `<=` : Less than or Equal to
#
# These can all be used in place of the `=` sign in queries where you are filtering by a numeric value. In this search, we find all the subjects who were over 50 years old when they entered the study. As the study entry date is day 0, `days_to_birth` is reported as a negative number:

# %%
Q('days_to_birth < 50*-365 ').subject.run().to_dataframe()
# Out:
# Getting results from database
# Total execution time: 4500 ms
#                    id                                         identifier  \
# 0           C3L-02170  [{'system': 'GDC', 'value': 'C3L-02170'}, {'sy...
# 1           C3L-02704  [{'system': 'GDC', 'value': 'C3L-02704'}, {'sy...
# 2           C3N-01214  [{'system': 'GDC', 'value': 'C3N-01214'}, {'sy...
# 3           C3N-01998  [{'system': 'GDC', 'value': 'C3N-01998'}, {'sy...
# 4           C3N-02339  [{'system': 'GDC', 'value': 'C3N-02339'}, {'sy...
# ..                ...                                                ...
# 95  GENIE-DFCI-027361  [{'system': 'GDC', 'value': 'GENIE-DFCI-027361'}]
# 96  GENIE-DFCI-033908  [{'system': 'GDC', 'value': 'GENIE-DFCI-033908'}]
# 97  GENIE-DFCI-035602  [{'system': 'GDC', 'value': 'GENIE-DFCI-035602'}]
# 98  GENIE-DFCI-035797  [{'system': 'GDC', 'value': 'GENIE-DFCI-035797'}]
# 99  GENIE-DFCI-036506  [{'system': 'GDC', 'value': 'GENIE-DFCI-036506'}]
#
#          species     sex          race               ethnicity  days_to_birth  \
# 0   Homo sapiens    male  not reported            not reported         -26717
# 1   Homo sapiens    male         white  not hispanic or latino         -19879
# 2   Homo sapiens    male  not reported            not reported         -22241
# 3   Homo sapiens    male  not reported            not reported         -25293
# 4   Homo sapiens    male  not reported            not reported         -28848
# ..           ...     ...           ...                     ...            ...
# 95  Homo sapiens    male         white  not hispanic or latino         -20819
# 96  Homo sapiens  female         white  not hispanic or latino         -19723
# 97  Homo sapiens  female         white  not hispanic or latino         -19358
# 98  Homo sapiens    male         white  not hispanic or latino         -20088
# 99  Homo sapiens    male         asian  not hispanic or latino         -19723
#
#                   subject_associated_project  vital_status  age_at_death  \
# 0    [CPTAC3-Discovery, CPTAC-3, cptac_lscc]         Alive           NaN
# 1     [cptac_gbm, CPTAC3-Discovery, CPTAC-3]         Alive           NaN
# 2   [CPTAC3-Discovery, CPTAC-3, cptac_ccrcc]         Alive           NaN
# 3     [cptac_pda, CPTAC3-Discovery, CPTAC-3]          Dead         186.0
# 4    [CPTAC3-Discovery, CPTAC-3, cptac_lscc]         Alive           NaN
# ..                                       ...           ...           ...
# 95                              [GENIE-DFCI]  Not Reported           NaN
# 96                              [GENIE-DFCI]  Not Reported           NaN
# 97                              [GENIE-DFCI]  Not Reported           NaN
# 98                              [GENIE-DFCI]  Not Reported           NaN
# 99                              [GENIE-DFCI]  Not Reported           NaN
#
#    cause_of_death
# 0            None
# 1            None
# 2    Not Reported
# 3            None
# 4            None
# ..            ...
# 95           None
# 96           None
# 97           None
# 98           None
# 99           None
#
# [100 rows x 11 columns]
